# %% [markdown]
# # Views and CTEs on Databricks, Cont'
#
# We are picking up from notebook [DE 3.2A - Views and CTEs on Databricks]($./DE 3.2A - Views and CTEs on Databricks) where we just reviewed the following two lists of tables<br/>
# and views with the special note that our global temp view **`global_temp_view_dist_gt_1000`** was not included in the first list.

# %% [markdown]
# -sandbox
#
#
#
# <img src="data:image/png;base64,..." />

# %% [markdown]
# With the Notebook's state reset, we need to re-initialize some of our lesson-specific configuration.
#
# Note: We will **NOT** be recreating the database for the second 1/2 of this lesson.

# %%
# %run ../Includes/Classroom-Setup-3.2B
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Python interpreter will be restarted.
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
#
# Predefined Paths:
#   DA.paths.working_dir: dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.2
#   DA.paths.user_db:     dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.2/3_2.db
#
# Setup completed in 0 seconds
# </div>

# %% [markdown]
# But, we do need to configure this session to use our database by default.

# %%
# %sql
USE ${da.db_name};
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Finally, run the following two cells to confirm that:
# 1. The table **`external_table`** still exists.
# 2. The view **`view_delays_abq_lax`** still exists.
# 3. The temp view **`temp_view_delays_gt_120`** does **NOT** exist.
# 3. The global temp view **`global_temp_view_dist_gt_1000`** does exist in the special **`global_temp`** database.
#
# <img src="https://files.training.databricks.com/images/icon_hint_24.png"> Hint: If you were to go back to the previous notebook and run **`SHOW TABLES`**<br/>
# again, all three tables and views from the current database will still be shown.

# %%
# %sql
SHOW TABLES;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>dbacademy_manujkumar_joshi_celebaltech_com_dewd_3_2</td><td>external_table</td><td>false</td></tr><tr><td>dbacademy_manujkumar_joshi_celebaltech_com_dewd_3_2</td><td>view_delays_abq_lax</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
SHOW TABLES IN global_temp;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>global_temp</td><td>global_temp_view_dist_gt_1000</td><td>true</td></tr></tbody></table></div>

# %% [markdown]
# #### As mentioned previously, temp views are tied to a Spark session and as such are not accessible...
# * After restarting a cluster
# * After detaching and reataching to a cluster
# * After installing a python package which in turn restarts the Python interpreter
# * Or from another notebook
#
# ...with the special exception of global temporary views.

# %% [markdown]
# Global temp views behave much like other temporary views but differ in one important way.
#
# They are added to the **`global_temp`** database that exists on the **`cluster`**.
#
# As long as the cluster is running, this database persists and any notebooks attached to the cluster can access its global temporary views.
#
# We can see this in action by running the follow cells:

# %%
# %sql
SELECT * FROM global_temp.global_temp_view_dist_gt_1000;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>delay</th><th>distance</th><th>origin</th><th>destination</th></tr></thead><tbody><tr><td>01012355</td><td>0</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01022355</td><td>158</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01032355</td><td>0</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01042355</td><td>0</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01052355</td><td>0</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01062355</td><td>0</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01072359</td><td>14</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01082358</td><td>-4</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01092358</td><td>20</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01102358</td><td>-2</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01112358</td><td>116</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01122358</td><td>0</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01132358</td><td>-10</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01142359</td><td>-17</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01152358</td><td>135</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01162358</td><td>-13</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01172358</td><td>-10</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01182358</td><td>-17</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01192358</td><td>-18</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01202358</td><td>-9</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01212359</td><td>0</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01222358</td><td>0</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01232358</td><td>44</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01242358</td><td>-6</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01252358</td><td>-12</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01262358</td><td>-22</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01272358</td><td>9</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01282359</td><td>-20</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01292358</td><td>17</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01302358</td><td>7</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01312358</td><td>-12</td><td>1586</td><td>ABQ</td><td>JFK</td></tr><tr><td>01011316</td><td>-8</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01010730</td><td>-4</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01020730</td><td>-2</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01020615</td><td>-4</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01021326</td><td>6</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01030730</td><td>-2</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01030615</td><td>0</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01031326</td><td>6</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01040730</td><td>-1</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01040615</td><td>0</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01041326</td><td>31</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01051326</td><td>26</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01050730</td><td>-2</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01050615</td><td>-2</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01061328</td><td>36</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01060730</td><td>44</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01060615</td><td>22</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01071328</td><td>-2</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01070615</td><td>-2</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01081328</td><td>16</td><td>1103</td><td>ABQ</td><td>ATL</td></tr><tr><td>01080 ...

# %% [markdown]
# ### Global temp views are "lost" when the cluster is restarted.
#
# Take our word for it, don't do it now, but if you were to restart the cluster, the above select statement would fail because the table would no longer exist.

# %% [markdown]
# ## Common Table Expressions (CTEs)
# CTEs can be used in a variety of contexts. Below, are a few examples of the different ways a CTE can be used in a query. First, an example of making multiple column aliases using a CTE.

# %%
# %sql
select * from external_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>delay</th><th>distance</th><th>origin</th><th>destination</th></tr></thead><tbody><tr><td>01011245</td><td>6</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01020600</td><td>-8</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01021245</td><td>-2</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01020605</td><td>-4</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01031245</td><td>-4</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01030605</td><td>0</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01041243</td><td>10</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01040605</td><td>28</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01051245</td><td>88</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01050605</td><td>9</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01061215</td><td>-6</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01061725</td><td>69</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01061230</td><td>0</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01060625</td><td>-3</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01070600</td><td>0</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01071725</td><td>0</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01071230</td><td>0</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01070625</td><td>0</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01071219</td><td>0</td><td>569</td><td>ABE</td><td>ORD</td></tr><tr><td>01080600</td><td>0</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01081230</td><td>33</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01080625</td><td>1</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01080607</td><td>5</td><td>569</td><td>ABE</td><td>ORD</td></tr><tr><td>01081219</td><td>54</td><td>569</td><td>ABE</td><td>ORD</td></tr><tr><td>01091215</td><td>43</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01090600</td><td>151</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01091725</td><td>0</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01091230</td><td>-4</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01090625</td><td>8</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01091219</td><td>83</td><td>569</td><td>ABE</td><td>ORD</td></tr><tr><td>01101215</td><td>-5</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01100600</td><td>-5</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01101725</td><td>7</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01101230</td><td>-8</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01100625</td><td>52</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01101219</td><td>0</td><td>569</td><td>ABE</td><td>ORD</td></tr><tr><td>01111215</td><td>127</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01110600</td><td>-9</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01110625</td><td>-4</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01121215</td><td>-5</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01121725</td><td>-1</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01131215</td><td>14</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01130600</td><td>-7</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01131725</td><td>-6</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01131230</td><td>-13</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01130625</td><td>29</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01131219</td><td>-8</td><td>569</td><td>ABE</td><td>ORD</td></tr><tr><td>01140600</td><td>-9</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01141725</td><td>-9</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01141230</td><td>-8</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01140625</td><td>-5</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01141219</td><td>-10</td><td>569</td><td>ABE</td><td>ORD</td></tr><t ...

# %%
# %sql
WITH flight_delays(
  total_delay_time,
  origin_airport,
  destination_airport
) AS (
  SELECT
    delay,
    origin,
    destination
  FROM
    external_table
)
SELECT
  *
FROM
  flight_delays
WHERE
  total_delay_time > 120
  AND origin_airport = "ATL"
  AND destination_airport = "DEN";
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_delay_time</th><th>origin_airport</th><th>destination_airport</th></tr></thead><tbody><tr><td>172</td><td>ATL</td><td>DEN</td></tr><tr><td>128</td><td>ATL</td><td>DEN</td></tr><tr><td>178</td><td>ATL</td><td>DEN</td></tr><tr><td>122</td><td>ATL</td><td>DEN</td></tr><tr><td>125</td><td>ATL</td><td>DEN</td></tr><tr><td>310</td><td>ATL</td><td>DEN</td></tr><tr><td>135</td><td>ATL</td><td>DEN</td></tr><tr><td>224</td><td>ATL</td><td>DEN</td></tr><tr><td>133</td><td>ATL</td><td>DEN</td></tr><tr><td>814</td><td>ATL</td><td>DEN</td></tr><tr><td>155</td><td>ATL</td><td>DEN</td></tr><tr><td>164</td><td>ATL</td><td>DEN</td></tr><tr><td>189</td><td>ATL</td><td>DEN</td></tr><tr><td>135</td><td>ATL</td><td>DEN</td></tr><tr><td>155</td><td>ATL</td><td>DEN</td></tr><tr><td>333</td><td>ATL</td><td>DEN</td></tr><tr><td>157</td><td>ATL</td><td>DEN</td></tr><tr><td>173</td><td>ATL</td><td>DEN</td></tr><tr><td>176</td><td>ATL</td><td>DEN</td></tr></tbody></table></div>

# %% [markdown]
# Next, is an example of a CTE in a CTE definition.

# %%
# %sql
WITH lax_bos AS (
  WITH origin_destination (origin_airport, destination_airport) AS (
    SELECT
      origin,
      destination
    FROM
      external_table
  )
  SELECT
    *
  FROM
    origin_destination
  WHERE
    origin_airport = 'LAX'
    AND destination_airport = 'BOS'
)
SELECT
  count(origin_airport) AS `Total Flights from LAX to BOS`
FROM
  lax_bos;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Total Flights from LAX to BOS</th></tr></thead><tbody><tr><td>684</td></tr></tbody></table></div>

# %% [markdown]
# Now, here is an example of a CTE in a subquery.

# %%
# %sql
SELECT
  max(total_delay) AS `Longest Delay (in minutes)`
FROM
  (
    WITH delayed_flights(total_delay) AS (
      SELECT
        delay
      FROM
        external_table
    )
    SELECT
      *
    FROM
      delayed_flights
  );
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Longest Delay (in minutes)</th></tr></thead><tbody><tr><td>995</td></tr></tbody></table></div>

# %% [markdown]
# We can also use a CTE in a subquery expression.

# %%
# %sql
SELECT
  (
    WITH distinct_origins AS (
      SELECT DISTINCT origin FROM external_table
    )
    SELECT
      count(origin) AS `Number of Distinct Origins`
    FROM
      distinct_origins
  ) AS `Number of Different Origin Airports`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Number of Different Origin Airports</th></tr></thead><tbody><tr><td>255</td></tr></tbody></table></div>

# %% [markdown]
# Finally, here is a CTE in a **`CREATE VIEW`** statement.

# %%
# %sql
CREATE OR REPLACE VIEW BOS_LAX 
AS WITH origin_destination(origin_airport, destination_airport) 
AS (SELECT origin, destination FROM external_table)
SELECT * FROM origin_destination
WHERE origin_airport = 'BOS' AND destination_airport = 'LAX';

SELECT count(origin_airport) AS `Number of Delayed Flights from BOS to LAX` FROM BOS_LAX;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Number of Delayed Flights from BOS to LAX</th></tr></thead><tbody><tr><td>677</td></tr></tbody></table></div>

# %% [markdown]
# ## Clean up
# We first drop the training database.

# %%
# %sql
DROP DATABASE ${da.db_name} CASCADE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Run the following cell to delete the tables and files associated with this lesson.

# %%
# %python 
DA.cleanup()

# %% [markdown]
# -sandbox
# &copy; 2022 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="https://help.databricks.com/">Support</a>
