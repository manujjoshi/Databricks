# %% [markdown]
# -sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Using the Delta Live Tables UI
#
# #### This demo will explore the DLT UI.
#
#
# ## Learning Objectives
# By the end of this lesson, you should be able to:
# * **Deploy a DLT(Delta Live tables) pipeline**
# * **Explore the resultant DAG**
# * **Execute an update of the pipeline**
# * **Look at metrics**

# %% [markdown]
# ## Run Setup
#
# The following cell is configured to reset this demo.

# %%
# %run ../../Includes/Classroom-Setup-8.1.1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Python interpreter will be restarted.
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Mounting course-specific datasets to <b>/mnt/training</b>...<br/>Datasets are already mounted to <b>/mnt/training</b>.
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Dropping the database &#34;dbacademy_manujkumar_joshi_celebaltech_com_dewd_dlt_demo_81&#34;
# Removing the working directory &#34;dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/dlt_demo_81&#34;
#
# Creating the database &#34;dbacademy_manujkumar_joshi_celebaltech_com_dewd_dlt_demo_81&#34;
#
# Predefined Paths:
#   DA.paths.working_dir:           dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/dlt_demo_81
#   DA.paths.user_db:               dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/dlt_demo_81/dlt_demo_81.db
#   DA.paths.data_source:           /mnt/training/healthcare
#   DA.paths.storage_location:      dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/dlt_demo_81/storage
#   DA.paths.data_landing_location: dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/dlt_demo_81/source/tracker
#
# Predefined tables in dbacademy_manujkumar_joshi_celebaltech_com_dewd_dlt_demo_81:
#   -none-
#
# Setup completed in 4 seconds
# </div>

# %% [markdown]
# **Execute the following cell to print out values that will be used during the following configuration steps.**

# %%
DA.print_pipeline_config()
# Out:
# <table style="width:100%">
#     <tr>
#         <td style="white-space:nowrap; width:1em">Pipeline Name:</td>
#         <td><input type="text" value="DLT-Demo-81-manujkumar.joshi@celebaltech.com" style="width:100%"></td></tr>
#     <tr>
#         <td style="white-space:nowrap; width:1em">Target:</td>
#         <td><input type="text" value="dbacademy_manujkumar_joshi_celebaltech_com_dewd_dlt_demo_81" style="width:100%"></td></tr>
#     <tr>
#         <td style="white-space:nowrap; width:1em">Storage Location:</td>
#         <td><input type="text" value="dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/dlt_demo_81/storage" style="width:100%"></td></tr>
#     <tr>
#         <td style="white-space:nowrap; width:1em">Notebook Path:</td>
#         <td><input type="text" value="/Users/manujkumar.joshi@celebaltech.com/Data-Engineering-with-Databricks/08 - Delta Live Tables/DE 8.1 DLT/DE 8.1.2 - SQL for Delta Live Tables" style="width:100%"></td></tr>
#     </table>

# %% [markdown]
# ## Create and Configure a Pipeline
#
# In this section you will create a pipeline using a notebook provided with the courseware. We'll explore the contents of the notebook in the following lesson.
#
# 1. Click the **Jobs** button on the sidebar.
# 1. Select the **Delta Live Tables** tab.
# 1. Click **Create Pipeline**.
# 1. Leave **Product Edition** as **Advanced**.
# 1. Fill in a **Pipeline Name** - because these names must be unique, we suggest using the **`Pipeline Name`** provided by the cell above.
# 1. For **Notebook Libraries**, use the navigator to locate and select the companion notebook called **DE 8.1.2 - SQL for Delta Live Tables**.
#    * Alternatively, you can copy the **`Notebook Path`** provided by the cell above and paste it into the provided field.
#    * Even though this document is a standard Databricks Notebook, the SQL syntax is specialized to DLT table declarations.
#    * We will be exploring the syntax in the exercise that follows.
# 1. In the **Target** field, specify the database name printed out next to **`Target`** in the cell above.<br/>
# This should follow the pattern **`dbacademy_<username>_dewd_dlt_demo_81`**
#    * This field is optional; if not specified, then tables will not be registered to a metastore, but will still be available in the DBFS. Refer to the <a href="https://docs.databricks.com/data-engineering/delta-live-tables/delta-live-tables-user-guide.html#publish-tables" target="_blank">documentation</a> for more information on this option.
# 1. In the **Storage location** field, copy the **`Storage Location`** path printed by the cell above.
#    * This optional field allows the user to specify a location to store logs, tables, and other information related to pipeline execution.
#    * If not specified, DLT will automatically generate a directory.
# 1. For **Pipeline Mode**, select **Triggered**
#    * This field specifies how the pipeline will be run.
#    * **Triggered** pipelines run once and then shut down until the next manual or scheduled update.
#    * **Continuous** pipelines run continuously, ingesting new data as it arrives. Choose the mode based on latency and cost requirements.
# 1. Uncheck the **Enable autoscaling** box, and set the number of workers to **`1`** (one).
#    * **Enable autoscaling**, **Min Workers** and **Max Workers** control the worker configuration for the underlying cluster processing the pipeline. Notice the DBU estimate provided, similar to that provided when configuring interactive clusters.
# 1. Click **Create**.

# %% [markdown]
# ## Run a Pipeline
#
# With a pipeline created, you will now run the pipeline.
#
# 1. Select **Development** to run the pipeline in development mode.
#   * Development mode provides for more expeditious iterative development by reusing the cluster (as opposed to creating a new cluster for each run) and disabling retries so that you can readily identify and fix errors.
#   * Refer to the <a href="https://docs.databricks.com/data-engineering/delta-live-tables/delta-live-tables-user-guide.html#optimize-execution" target="_blank">documentation</a> for more information on this feature.
# 2. Click **Start**.
#
# The initial run will take several minutes while a cluster is provisioned.
#
# Subsequent runs will be appreciably quicker.

# %% [markdown]
# ## Exploring the DAG
#
# As the pipeline completes, the execution flow is graphed.
#
# Selecting the tables reviews the details.
#
# Select **sales_orders_cleaned**. Notice the results reported in the **Data Quality** section. Because this flow has data expectations declared, those metrics are tracked here. No records are dropped because the constraint is declared in a way that allows violating records to be included in the output. This will be covered in more details in the next exercise.

# %% [markdown]
# -sandbox
# &copy; 2022 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="https://help.databricks.com/">Support</a>
