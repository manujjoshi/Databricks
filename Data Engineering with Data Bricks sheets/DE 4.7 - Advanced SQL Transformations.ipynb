# %% [markdown]
# -sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Advanced SQL Transformations
#
# **Querying tabular data stored in the data lakehouse with Spark SQL is easy, efficient, and fast.**
#
# This gets more complicated as the data structure becomes less regular, when many tables need to be used in a single query, or when the shape of data needs to be changed dramatically. This notebook introduces a number of functions present in Spark SQL to help engineers complete even the most complicated transformations.
#
# ## Learning Objectives
# By the end of this lesson, you should be able to:
# - Use **`.`** and **`:`** syntax to query nested data
# - Work with JSON
# - Flatten and unpacking arrays and structs
# - Combine datasets using joins and set operators
# - Reshape data using pivot tables
# - Use higher order functions for working with arrays

# %% [markdown]
# ## Run Setup
#
# The setup script will create the data and declare necessary values for the rest of this notebook to execute.

# %%
# %run ../Includes/Classroom-Setup-4.7
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Python interpreter will be restarted.
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
# Creating the database &#34;dbacademy_manujkumar_joshi_celebaltech_com_dewd_4_7&#34;
# Skipping install to &#34;dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/source/eltwss&#34;, dataset already exists
#
# Cloning the sales table from dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/source/eltwss/delta/sales_hist...(7 seconds / 10,510 records)
# Cloning the events table from dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/source/eltwss/delta/events_hist...(4 seconds / 485,696 records)
# Cloning the events_update table from dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/source/eltwss/delta/events_update...(4 seconds / 1,927 records)
# Cloning the events_raw table from dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/source/eltwss/delta/events_raw...(4 seconds / 2,252 records)
# Cloning the item_lookup table from dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/source/eltwss/delta/item_lookup...(3 seconds / 12 records)
#
# Predefined Paths:
#   DA.paths.working_dir: dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/4.7
#   DA.paths.user_db:     dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/4.7/4_7.db
#   DA.paths.datasets:    dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/source/eltwss
#
# Predefined tables in dbacademy_manujkumar_joshi_celebaltech_com_dewd_4_7:
#   events
#   events_raw
#   events_update
#   item_lookup
#   sales
#
# Setup completed in 24 seconds
# </div>

# %% [markdown]
# ## Interacting with JSON Data
#
# The **`events_raw`** table was registered against data representing a Kafka payload.
#
# In most cases, Kafka data will be binary-encoded JSON values. We'll cast the **`key`** and **`value`** as strings below to look at these in a human-readable format.

# %%
# %sql
CREATE OR REPLACE TEMP VIEW events_strings AS
  SELECT string(key), string(value) 
  FROM events_raw;
  
SELECT * FROM events_strings
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th></tr></thead><tbody><tr><td>UA000000107384208</td><td>{"device":"macOS","ecommerce":{},"event_name":"checkout","event_previous_timestamp":1593880801027797,"event_timestamp":1593880822506642,"geo":{"city":"Traverse City","state":"MI"},"items":[{"item_id":"M_STAN_T","item_name":"Standard Twin Mattress","item_revenue_in_usd":595.0,"price_in_usd":595.0,"quantity":1}],"traffic_source":"google","user_first_touch_timestamp":1593879413256859,"user_id":"UA000000107384208"}</td></tr><tr><td>UA000000107388621</td><td>{"device":"Windows","ecommerce":{},"event_name":"email_coupon","event_previous_timestamp":1593880770092554,"event_timestamp":1593880829320848,"geo":{"city":"Hickory","state":"NC"},"items":[{"coupon":"NEWBED10","item_id":"M_STAN_F","item_name":"Standard Full Mattress","item_revenue_in_usd":850.5,"price_in_usd":945.0,"quantity":1}],"traffic_source":"direct","user_first_touch_timestamp":1593879889503719,"user_id":"UA000000107388621"}</td></tr><tr><td>UA000000107397512</td><td>{"device":"Windows","ecommerce":{},"event_name":"main","event_timestamp":1593880824305898,"geo":{"city":"Fargo","state":"ND"},"items":[],"traffic_source":"facebook","user_first_touch_timestamp":1593880824305898,"user_id":"UA000000107397512"}</td></tr><tr><td>UA000000107369427</td><td>{"device":"Android","ecommerce":{},"event_name":"add_item","event_previous_timestamp":1593880753875794,"event_timestamp":1593880826675403,"geo":{"city":"Chicago","state":"IL"},"items":[{"item_id":"M_STAN_T","item_name":"Standard Twin Mattress","item_revenue_in_usd":595.0,"price_in_usd":595.0,"quantity":1}],"traffic_source":"facebook","user_first_touch_timestamp":1593877772975990,"user_id":"UA000000107369427"}</td></tr><tr><td>UA000000107393216</td><td>{"device":"macOS","ecommerce":{},"event_name":"checkout","event_previous_timestamp":1593880741311315,"event_timestamp":1593880830140019,"geo":{"city":"Fargo","state":"ND"},"items":[{"item_id":"M_STAN_F","item_name":"Standard Full Mattress","item_revenue_in_usd":945.0,"price_in_usd":945.0,"quantity":1}],"traffic_source":"google","user_first_touch_timestamp":1593880382734336,"user_id":"UA000000107393216"}</td></tr><tr><td>UA000000107325264</td><td>{"device":"Android","ecommerce":{"purchase_revenue_in_usd":1195.0,"total_item_quantity":1,"unique_items":1},"event_name":"finalize","event_previous_timestamp":1593876666372094,"event_timestamp":1593880830038130,"geo":{"city":"Tuttle","state":"OK"},"items":[{"item_id":"M_STAN_K","item_name":"Standard King Mattress","item_revenue_in_usd":1195.0,"price_in_usd":1195.0,"quantity":1}],"traffic_source":"direct","user_first_touch_timestamp":1593872552663730,"user_id":"UA000000107325264"}</td></tr><tr><td>UA000000107377602</td><td>{"device":"iOS","ecommerce":{},"event_name":"email_coupon","event_previous_timestamp":1593880697501673,"event_timestamp":1593880832779143,"geo":{"city":"Vineland","state":"NJ"},"items":[],"traffic_source":"direct","user_first_touch_timestamp":1593878686736308,"user_id":"UA000000107377602"}</td></tr><tr><td>UA000000107397643</td><td>{"device":"iOS","ecommerce":{},"event_name":"main","event_timestamp":1593880838082657,"geo":{"city":"Minneapolis","state":"MN"},"items":[],"traffic_source":"google","user_first_touch_timestamp":1593880838082657,"user_id":"UA000000107397643"}</td></tr><tr><td>UA000000107369021</td><td>{"device":"iOS","ecommerce":{},"event_name":"reviews","event_previous_timestamp":1593880064030570,"event_timestamp":1593880834060045,"geo":{"city":"Spencer","state":"WV"},"items":[],"traffic_source":"google","user_first_touch_timestamp":1593877728194714,"user_id":"UA000000107369021"}</td></tr><tr><td>UA000000107388503</td><td>{"device":"Windows","ecommerce":{},"event_name":"delivery","event_previous_timestamp":1593879876501779,"event_timestamp":1593880838455915,"geo":{"city":"Houston","state":"TX"},"items":[],"traffic_source" ...

# %% [markdown]
# #### Spark SQL has built-in functionality to directly interact with JSON data stored as strings. We can use the **`:`** syntax to traverse nested data structures.

# %%
# %sql
SELECT value:device, value:geo:city 
FROM events_strings
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device</th><th>city</th></tr></thead><tbody><tr><td>macOS</td><td>Traverse City</td></tr><tr><td>Windows</td><td>Hickory</td></tr><tr><td>Windows</td><td>Fargo</td></tr><tr><td>Android</td><td>Chicago</td></tr><tr><td>macOS</td><td>Fargo</td></tr><tr><td>Android</td><td>Tuttle</td></tr><tr><td>iOS</td><td>Vineland</td></tr><tr><td>iOS</td><td>Minneapolis</td></tr><tr><td>iOS</td><td>Spencer</td></tr><tr><td>Windows</td><td>Houston</td></tr><tr><td>Windows</td><td>Fort Lauderdale</td></tr><tr><td>Android</td><td>Tuttle</td></tr><tr><td>macOS</td><td>Fargo</td></tr><tr><td>macOS</td><td>Fargo</td></tr><tr><td>Chrome OS</td><td>Fremont</td></tr><tr><td>iOS</td><td>Vineland</td></tr><tr><td>Chrome OS</td><td>Fremont</td></tr><tr><td>iOS</td><td>Blanchard</td></tr><tr><td>macOS</td><td>Bixby</td></tr><tr><td>Android</td><td>Chicago</td></tr><tr><td>Windows</td><td>Hickory</td></tr><tr><td>iOS</td><td>Laurel</td></tr><tr><td>Chrome OS</td><td>Deltona</td></tr><tr><td>Linux</td><td>Fayetteville</td></tr><tr><td>iOS</td><td>Laurel</td></tr><tr><td>Windows</td><td>Charlotte</td></tr><tr><td>Android</td><td>Evansville</td></tr><tr><td>Android</td><td>Kenyon</td></tr><tr><td>iOS</td><td>Brighton</td></tr><tr><td>Android</td><td>Licking</td></tr><tr><td>Chrome OS</td><td>Deltona</td></tr><tr><td>macOS</td><td>Cheney</td></tr><tr><td>Android</td><td>Evansville</td></tr><tr><td>Android</td><td>Hanahan</td></tr><tr><td>Windows</td><td>Las Vegas</td></tr><tr><td>macOS</td><td>Houston</td></tr><tr><td>Windows</td><td>Charlotte</td></tr><tr><td>Android</td><td>Fort Wayne</td></tr><tr><td>Android</td><td>Plano</td></tr><tr><td>iOS</td><td>Newport</td></tr><tr><td>Windows</td><td>Anaheim</td></tr><tr><td>Android</td><td>Reno</td></tr><tr><td>Chrome OS</td><td>Lakewood</td></tr><tr><td>Android</td><td>Brentwood</td></tr><tr><td>macOS</td><td>Fishers</td></tr><tr><td>Windows</td><td>Madera</td></tr><tr><td>Linux</td><td>Garden City</td></tr><tr><td>Windows</td><td>Pomona</td></tr><tr><td>Android</td><td>Laredo</td></tr><tr><td>macOS</td><td>Fishers</td></tr><tr><td>Windows</td><td>Madera</td></tr><tr><td>Windows</td><td>Anaheim</td></tr><tr><td>Android</td><td>Brentwood</td></tr><tr><td>macOS</td><td>Columbus</td></tr><tr><td>Android</td><td>Brentwood</td></tr><tr><td>macOS</td><td>New York</td></tr><tr><td>Android</td><td>Seattle</td></tr><tr><td>iOS</td><td>Rio Rancho</td></tr><tr><td>Linux</td><td>New York</td></tr><tr><td>Linux</td><td>New York</td></tr><tr><td>Windows</td><td>Yonkers</td></tr><tr><td>Windows</td><td>Jacksonville</td></tr><tr><td>iOS</td><td>Lubbock</td></tr><tr><td>Android</td><td>Gillette</td></tr><tr><td>iOS</td><td>Rio Rancho</td></tr><tr><td>Windows</td><td>Yonkers</td></tr><tr><td>Android</td><td>East Providence</td></tr><tr><td>Windows</td><td>New York</td></tr><tr><td>macOS</td><td>Trinity</td></tr><tr><td>iOS</td><td>Lomita</td></tr><tr><td>Linux</td><td>New York</td></tr><tr><td>Android</td><td>Gillette</td></tr><tr><td>Android</td><td>Vernon</td></tr><tr><td>Android</td><td>New York</td></tr><tr><td>iOS</td><td>Westbrook</td></tr><tr><td>macOS</td><td>Fishers</td></tr><tr><td>iOS</td><td>Lomita</td></tr><tr><td>Android</td><td>New York</td></tr><tr><td>Android</td><td>New York</td></tr><tr><td>Android</td><td>Vernon</td></tr><tr><td>macOS</td><td>Lakewood</td></tr><tr><td>Windows</td><td>Denver</td></tr><tr><td>Android</td><td>Vernon</td></tr><tr><td>Windows</td><td>Denver</td></tr><tr><td>Android</td><td>New York</td></tr><tr><td>Android</td><td>Seattle</td></tr><tr><td>Android</td><td>San Bernardino</td></tr><tr><td>Windows</td><td>New York</td></tr><tr><td>Android</td><td>East Providence</td></tr><tr><td>macOS</td><td>New York</td></tr><tr><td>Android</td><td>Vernon</td></tr><tr><td>Android</td><td>East Providence</td></tr><tr><td>Android</td><td>East Providence</td></tr><tr><td>Linux</td><td>New  ...

# %% [markdown]
# #### Spark SQL also has the ability to parse JSON objects into struct types (a native Spark type with nested attributes).
#
# However, the **`from_json`** function requires a schema. To derive the schema of our current data, we'll start by executing a query we know will return a JSON value with no null fields.

# %%
# %sql
SELECT value 
FROM events_strings 
WHERE value:event_name = "finalize" 
ORDER BY key
LIMIT 3
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th></tr></thead><tbody><tr><td>{"device":"Linux","ecommerce":{"purchase_revenue_in_usd":1047.6,"total_item_quantity":2,"unique_items":2},"event_name":"finalize","event_previous_timestamp":1593879787820475,"event_timestamp":1593879948830076,"geo":{"city":"Huntington Park","state":"CA"},"items":[{"coupon":"NEWBED10","item_id":"M_STAN_Q","item_name":"Standard Queen Mattress","item_revenue_in_usd":940.5,"price_in_usd":1045.0,"quantity":1},{"coupon":"NEWBED10","item_id":"P_DOWN_S","item_name":"Standard Down Pillow","item_revenue_in_usd":107.10000000000001,"price_in_usd":119.0,"quantity":1}],"traffic_source":"email","user_first_touch_timestamp":1593583891412316,"user_id":"UA000000106459577"}</td></tr><tr><td>{"device":"Windows","ecommerce":{"purchase_revenue_in_usd":1525.5,"total_item_quantity":1,"unique_items":1},"event_name":"finalize","event_previous_timestamp":1593880123694767,"event_timestamp":1593880236431848,"geo":{"city":"Arlington","state":"TX"},"items":[{"coupon":"NEWBED10","item_id":"M_PREM_F","item_name":"Premium Full Mattress","item_revenue_in_usd":1525.5,"price_in_usd":1695.0,"quantity":1}],"traffic_source":"email","user_first_touch_timestamp":1593623684582377,"user_id":"UA000000106581126"}</td></tr><tr><td>{"device":"Android","ecommerce":{"purchase_revenue_in_usd":940.5,"total_item_quantity":1,"unique_items":1},"event_name":"finalize","event_previous_timestamp":1593879716269372,"event_timestamp":1593879731743920,"geo":{"city":"Leitchfield","state":"KY"},"items":[{"coupon":"NEWBED10","item_id":"M_STAN_Q","item_name":"Standard Queen Mattress","item_revenue_in_usd":940.5,"price_in_usd":1045.0,"quantity":1}],"traffic_source":"email","user_first_touch_timestamp":1593632616907199,"user_id":"UA000000106629972"}</td></tr></tbody></table></div>

# %% [markdown]
# #### Spark SQL also has a **`schema_of_json`** function to derive the JSON schema from an example. Here, we copy and paste an example JSON to the function and chain it into the **`from_json`** function to cast our **`value`** field to a struct type.

# %%
# %sql
CREATE OR REPLACE TEMP VIEW parsed_events AS
  SELECT from_json(value, schema_of_json('{"device":"Linux","ecommerce":{"purchase_revenue_in_usd":1075.5,"total_item_quantity":1,"unique_items":1},"event_name":"finalize","event_previous_timestamp":1593879231210816,"event_timestamp":1593879335779563,"geo":{"city":"Houston","state":"TX"},"items":[{"coupon":"NEWBED10","item_id":"M_STAN_K","item_name":"Standard King Mattress","item_revenue_in_usd":1075.5,"price_in_usd":1195.0,"quantity":1}],"traffic_source":"email","user_first_touch_timestamp":1593454417513109,"user_id":"UA000000106116176"}')) AS json 
  FROM events_strings;
  
SELECT * FROM parsed_events
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>json</th></tr></thead><tbody><tr><td>List(macOS, List(null, null, null), checkout, 1593880801027797, 1593880822506642, List(Traverse City, MI), List(List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1)), google, 1593879413256859, UA000000107384208)</td></tr><tr><td>List(Windows, List(null, null, null), email_coupon, 1593880770092554, 1593880829320848, List(Hickory, NC), List(List(NEWBED10, M_STAN_F, Standard Full Mattress, 850.5, 945.0, 1)), direct, 1593879889503719, UA000000107388621)</td></tr><tr><td>List(Windows, List(null, null, null), main, null, 1593880824305898, List(Fargo, ND), List(), facebook, 1593880824305898, UA000000107397512)</td></tr><tr><td>List(Android, List(null, null, null), add_item, 1593880753875794, 1593880826675403, List(Chicago, IL), List(List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1)), facebook, 1593877772975990, UA000000107369427)</td></tr><tr><td>List(macOS, List(null, null, null), checkout, 1593880741311315, 1593880830140019, List(Fargo, ND), List(List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1)), google, 1593880382734336, UA000000107393216)</td></tr><tr><td>List(Android, List(1195.0, 1, 1), finalize, 1593876666372094, 1593880830038130, List(Tuttle, OK), List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1)), direct, 1593872552663730, UA000000107325264)</td></tr><tr><td>List(iOS, List(null, null, null), email_coupon, 1593880697501673, 1593880832779143, List(Vineland, NJ), List(), direct, 1593878686736308, UA000000107377602)</td></tr><tr><td>List(iOS, List(null, null, null), main, null, 1593880838082657, List(Minneapolis, MN), List(), google, 1593880838082657, UA000000107397643)</td></tr><tr><td>List(iOS, List(null, null, null), reviews, 1593880064030570, 1593880834060045, List(Spencer, WV), List(), google, 1593877728194714, UA000000107369021)</td></tr><tr><td>List(Windows, List(null, null, null), delivery, 1593879876501779, 1593880838455915, List(Houston, TX), List(), facebook, 1593879876501779, UA000000107388503)</td></tr><tr><td>List(Windows, List(null, null, null), main, null, 1593880834503328, List(Fort Lauderdale, FL), List(), facebook, 1593880834503328, UA000000107397605)</td></tr><tr><td>List(Android, List(1195.0, 1, 1), finalize, 1593876666372094, 1593880830038130, List(Tuttle, OK), List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1)), direct, 1593872552663730, UA000000107325264)</td></tr><tr><td>List(macOS, List(null, null, null), checkout, 1593880741311315, 1593880830140019, List(Fargo, ND), List(List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1)), google, 1593880382734336, UA000000107393216)</td></tr><tr><td>List(macOS, List(null, null, null), guest, 1593880830140019, 1593880836873161, List(Fargo, ND), List(List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1)), google, 1593880382734336, UA000000107393216)</td></tr><tr><td>List(Chrome OS, List(null, null, null), main, null, 1593880832658403, List(Fremont, NE), List(), google, 1593880832658403, UA000000107397586)</td></tr><tr><td>List(iOS, List(null, null, null), email_coupon, 1593880697501673, 1593880832779143, List(Vineland, NJ), List(), direct, 1593878686736308, UA000000107377602)</td></tr><tr><td>List(Chrome OS, List(null, null, null), main, null, 1593880832658403, List(Fremont, NE), List(), google, 1593880832658403, UA000000107397586)</td></tr><tr><td>List(iOS, List(null, null, null), warranty, 1593880776946615, 1593880832821465, List(Blanchard, OK), List(), facebook, 1593879936686872, UA000000107389053)</td></tr><tr><td>List(macOS, List(null, null, null), pillows, null, 1593880837721570, List(Bixby, OK), List(), instagram, 1593880837721570, UA000000107397639)</td></tr><tr><td>List(Android, List(null, null, null), add_item, 1593880753875794, 1593880826675403, List(Chicago, IL), List(List(null, M_STAN_T, Standard Twin Mattress, 595. ...

# %% [markdown]
# #### Once a JSON string is unpacked to a struct type, Spark supports **`*`** (star) unpacking to flatten fields into columns.

# %%
# %sql
CREATE OR REPLACE TEMP VIEW new_events_final AS
  SELECT json.* 
  FROM parsed_events;
  
SELECT * FROM new_events_final
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device</th><th>ecommerce</th><th>event_name</th><th>event_previous_timestamp</th><th>event_timestamp</th><th>geo</th><th>items</th><th>traffic_source</th><th>user_first_touch_timestamp</th><th>user_id</th></tr></thead><tbody><tr><td>macOS</td><td>List(null, null, null)</td><td>checkout</td><td>1593880801027797</td><td>1593880822506642</td><td>List(Traverse City, MI)</td><td>List(List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1))</td><td>google</td><td>1593879413256859</td><td>UA000000107384208</td></tr><tr><td>Windows</td><td>List(null, null, null)</td><td>email_coupon</td><td>1593880770092554</td><td>1593880829320848</td><td>List(Hickory, NC)</td><td>List(List(NEWBED10, M_STAN_F, Standard Full Mattress, 850.5, 945.0, 1))</td><td>direct</td><td>1593879889503719</td><td>UA000000107388621</td></tr><tr><td>Windows</td><td>List(null, null, null)</td><td>main</td><td>null</td><td>1593880824305898</td><td>List(Fargo, ND)</td><td>List()</td><td>facebook</td><td>1593880824305898</td><td>UA000000107397512</td></tr><tr><td>Android</td><td>List(null, null, null)</td><td>add_item</td><td>1593880753875794</td><td>1593880826675403</td><td>List(Chicago, IL)</td><td>List(List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1))</td><td>facebook</td><td>1593877772975990</td><td>UA000000107369427</td></tr><tr><td>macOS</td><td>List(null, null, null)</td><td>checkout</td><td>1593880741311315</td><td>1593880830140019</td><td>List(Fargo, ND)</td><td>List(List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1))</td><td>google</td><td>1593880382734336</td><td>UA000000107393216</td></tr><tr><td>Android</td><td>List(1195.0, 1, 1)</td><td>finalize</td><td>1593876666372094</td><td>1593880830038130</td><td>List(Tuttle, OK)</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>direct</td><td>1593872552663730</td><td>UA000000107325264</td></tr><tr><td>iOS</td><td>List(null, null, null)</td><td>email_coupon</td><td>1593880697501673</td><td>1593880832779143</td><td>List(Vineland, NJ)</td><td>List()</td><td>direct</td><td>1593878686736308</td><td>UA000000107377602</td></tr><tr><td>iOS</td><td>List(null, null, null)</td><td>main</td><td>null</td><td>1593880838082657</td><td>List(Minneapolis, MN)</td><td>List()</td><td>google</td><td>1593880838082657</td><td>UA000000107397643</td></tr><tr><td>iOS</td><td>List(null, null, null)</td><td>reviews</td><td>1593880064030570</td><td>1593880834060045</td><td>List(Spencer, WV)</td><td>List()</td><td>google</td><td>1593877728194714</td><td>UA000000107369021</td></tr><tr><td>Windows</td><td>List(null, null, null)</td><td>delivery</td><td>1593879876501779</td><td>1593880838455915</td><td>List(Houston, TX)</td><td>List()</td><td>facebook</td><td>1593879876501779</td><td>UA000000107388503</td></tr><tr><td>Windows</td><td>List(null, null, null)</td><td>main</td><td>null</td><td>1593880834503328</td><td>List(Fort Lauderdale, FL)</td><td>List()</td><td>facebook</td><td>1593880834503328</td><td>UA000000107397605</td></tr><tr><td>Android</td><td>List(1195.0, 1, 1)</td><td>finalize</td><td>1593876666372094</td><td>1593880830038130</td><td>List(Tuttle, OK)</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>direct</td><td>1593872552663730</td><td>UA000000107325264</td></tr><tr><td>macOS</td><td>List(null, null, null)</td><td>checkout</td><td>1593880741311315</td><td>1593880830140019</td><td>List(Fargo, ND)</td><td>List(List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1))</td><td>google</td><td>1593880382734336</td><td>UA000000107393216</td></tr><tr><td>macOS</td><td>List(null, null, null)</td><td>guest</td><td>1593880830140019</td><td>1593880836873161</td><td>List(Fargo, ND)</td><td>List(List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1))</td><td>google</td><td>1593880382734336</td><td>UA000000107393216</td> ...

# %% [markdown]
# ## Explore Data Structures
#
# Spark SQL has robust syntax for working with complex and nested data types.
#
# Start by looking at the fields in the **`events`** table.

# %%
# %sql
DESCRIBE events
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>device</td><td>string</td><td></td></tr><tr><td>ecommerce</td><td>struct<purchase_revenue_in_usd:double,total_item_quantity:bigint,unique_items:bigint></td><td></td></tr><tr><td>event_name</td><td>string</td><td></td></tr><tr><td>event_previous_timestamp</td><td>bigint</td><td></td></tr><tr><td>event_timestamp</td><td>bigint</td><td></td></tr><tr><td>geo</td><td>struct<city:string,state:string></td><td></td></tr><tr><td>items</td><td>array<struct<coupon:string,item_id:string,item_name:string,item_revenue_in_usd:double,price_in_usd:double,quantity:bigint>></td><td></td></tr><tr><td>traffic_source</td><td>string</td><td></td></tr><tr><td>user_first_touch_timestamp</td><td>bigint</td><td></td></tr><tr><td>user_id</td><td>string</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Partitioning</td><td></td><td></td></tr><tr><td>Not partitioned</td><td></td><td></td></tr></tbody></table></div>

# %% [markdown]
# The **`ecommerce`** field is a struct that contains a double and 2 longs.
#
# We can interact with the subfields in this field using standard **`.`** syntax similar to how we might traverse nested data in JSON.

# %%
# %sql
SELECT ecommerce.purchase_revenue_in_usd 
FROM events
WHERE ecommerce.purchase_revenue_in_usd IS NOT NULL
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>purchase_revenue_in_usd</th></tr></thead><tbody><tr><td>1795.0</td></tr><tr><td>1045.0</td></tr><tr><td>535.5</td></tr><tr><td>1095.0</td></tr><tr><td>940.5</td></tr><tr><td>1995.0</td></tr><tr><td>940.5</td></tr><tr><td>1045.0</td></tr><tr><td>1695.0</td></tr><tr><td>1045.0</td></tr><tr><td>1045.0</td></tr><tr><td>595.0</td></tr><tr><td>2140.0</td></tr><tr><td>850.5</td></tr><tr><td>1790.0</td></tr><tr><td>1615.5</td></tr><tr><td>1045.0</td></tr><tr><td>1045.0</td></tr><tr><td>940.5</td></tr><tr><td>940.5</td></tr><tr><td>1195.0</td></tr><tr><td>119.0</td></tr><tr><td>59.0</td></tr><tr><td>940.5</td></tr><tr><td>1195.0</td></tr><tr><td>1045.0</td></tr><tr><td>2556.0</td></tr><tr><td>940.5</td></tr><tr><td>1795.5</td></tr><tr><td>2556.0</td></tr><tr><td>945.0</td></tr><tr><td>1195.0</td></tr><tr><td>1045.0</td></tr><tr><td>53.1</td></tr><tr><td>985.5</td></tr><tr><td>535.5</td></tr><tr><td>1095.0</td></tr><tr><td>985.5</td></tr><tr><td>1615.5</td></tr><tr><td>1795.0</td></tr><tr><td>1795.5</td></tr><tr><td>850.5</td></tr><tr><td>1104.0</td></tr><tr><td>1195.0</td></tr><tr><td>1190.0</td></tr><tr><td>850.5</td></tr><tr><td>535.5</td></tr><tr><td>940.5</td></tr><tr><td>535.5</td></tr><tr><td>1195.0</td></tr><tr><td>940.5</td></tr><tr><td>1195.0</td></tr><tr><td>850.5</td></tr><tr><td>595.0</td></tr><tr><td>1075.5</td></tr><tr><td>595.0</td></tr><tr><td>535.5</td></tr><tr><td>535.5</td></tr><tr><td>1795.5</td></tr><tr><td>1075.5</td></tr><tr><td>1045.0</td></tr><tr><td>1075.5</td></tr><tr><td>143.1</td></tr><tr><td>535.5</td></tr><tr><td>1104.0</td></tr><tr><td>119.0</td></tr><tr><td>1045.0</td></tr><tr><td>1195.0</td></tr><tr><td>1695.0</td></tr><tr><td>1995.0</td></tr><tr><td>595.0</td></tr><tr><td>1075.5</td></tr><tr><td>595.0</td></tr><tr><td>2899.0</td></tr><tr><td>59.0</td></tr><tr><td>940.5</td></tr><tr><td>1045.0</td></tr><tr><td>595.0</td></tr><tr><td>850.5</td></tr><tr><td>59.0</td></tr><tr><td>1095.0</td></tr><tr><td>595.0</td></tr><tr><td>1195.0</td></tr><tr><td>1075.5</td></tr><tr><td>535.5</td></tr><tr><td>850.5</td></tr><tr><td>1790.0</td></tr><tr><td>595.0</td></tr><tr><td>1075.5</td></tr><tr><td>159.0</td></tr><tr><td>1075.5</td></tr><tr><td>1525.5</td></tr><tr><td>1045.0</td></tr><tr><td>1071.0</td></tr><tr><td>1795.0</td></tr><tr><td>940.5</td></tr><tr><td>1045.0</td></tr><tr><td>850.5</td></tr><tr><td>1195.0</td></tr><tr><td>940.5</td></tr><tr><td>678.6</td></tr><tr><td>107.10000000000001</td></tr><tr><td>595.0</td></tr><tr><td>595.0</td></tr><tr><td>595.0</td></tr><tr><td>940.5</td></tr><tr><td>940.5</td></tr><tr><td>1274.0</td></tr><tr><td>535.5</td></tr><tr><td>985.5</td></tr><tr><td>985.5</td></tr><tr><td>1195.0</td></tr><tr><td>535.5</td></tr><tr><td>595.0</td></tr><tr><td>1195.0</td></tr><tr><td>595.0</td></tr><tr><td>1195.0</td></tr><tr><td>535.5</td></tr><tr><td>2385.0</td></tr><tr><td>535.5</td></tr><tr><td>595.0</td></tr><tr><td>595.0</td></tr><tr><td>940.5</td></tr><tr><td>595.0</td></tr><tr><td>1195.0</td></tr><tr><td>1995.0</td></tr><tr><td>1124.0</td></tr><tr><td>1095.0</td></tr><tr><td>1045.0</td></tr><tr><td>1615.5</td></tr><tr><td>1686.6</td></tr><tr><td>535.5</td></tr><tr><td>993.6</td></tr><tr><td>1195.0</td></tr><tr><td>940.5</td></tr><tr><td>1195.0</td></tr><tr><td>945.0</td></tr><tr><td>1640.0</td></tr><tr><td>940.5</td></tr><tr><td>535.5</td></tr><tr><td>985.5</td></tr><tr><td>1190.0</td></tr><tr><td>940.5</td></tr><tr><td>850.5</td></tr><tr><td>1195.0</td></tr><tr><td>654.0</td></tr><tr><td>595.0</td></tr><tr><td>1045.0</td></tr><tr><td>850.5</td></tr><tr><td>1195.0</td></tr><tr><td>1254.0</td></tr><tr><td>1195.0</td></tr><tr><td>1045.0</td></tr><tr><td>850.5</td></tr><tr><td>945.0</td></tr><tr><td>945.0</td></tr><tr><td>1195.0</td></tr><tr><td>71.10000000000001</td></tr><tr><td>535.5</td></tr><tr><td>1195.0</td></tr><tr><td>107.10000000000001</td></tr><tr><td>1195.0</t ...

# %% [markdown]
# ## Explode Arrays
# The **`items`** field in the **`events`** table is an array of structs.
#
# Spark SQL has a number of functions specifically to deal with arrays.
#
# The **`explode`** function lets us put each element in an array on its own row.

# %%
# %sql
SELECT user_id, event_timestamp, event_name, explode(items) AS item 
FROM events
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>event_timestamp</th><th>event_name</th><th>item</th></tr></thead><tbody><tr><td>UA000000106466918</td><td>1593595620017592</td><td>add_item</td><td>List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1)</td></tr><tr><td>UA000000106541016</td><td>1593617822519726</td><td>guest</td><td>List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1)</td></tr><tr><td>UA000000106537762</td><td>1593623248104571</td><td>finalize</td><td>List(null, M_PREM_Q, Premium Queen Mattress, 1795.0, 1795.0, 1)</td></tr><tr><td>UA000000106544798</td><td>1593619763160248</td><td>guest</td><td>List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1)</td></tr><tr><td>UA000000106527304</td><td>1593733998028702</td><td>cart</td><td>List(NEWBED10, M_PREM_T, Premium Twin Mattress, 985.5, 1095.0, 1)</td></tr><tr><td>UA000000106506669</td><td>1593817553389549</td><td>cart</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td></tr><tr><td>UA000000106550039</td><td>1593624602547189</td><td>cc_info</td><td>List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1)</td></tr><tr><td>UA000000106546519</td><td>1593618423460068</td><td>cart</td><td>List(null, M_PREM_Q, Premium Queen Mattress, 1795.0, 1795.0, 1)</td></tr><tr><td>UA000000106550923</td><td>1593621069581377</td><td>cart</td><td>List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1)</td></tr><tr><td>UA000000106550923</td><td>1593621069581377</td><td>cart</td><td>List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1)</td></tr><tr><td>UA000000106515529</td><td>1593809961957359</td><td>cc_info</td><td>List(NEWBED10, P_FOAM_S, Standard Foam Pillow, 53.1, 59.0, 1)</td></tr><tr><td>UA000000106457337</td><td>1593574627242401</td><td>add_item</td><td>List(null, M_PREM_T, Premium Twin Mattress, 1095.0, 1095.0, 1)</td></tr><tr><td>UA000000106526202</td><td>1593614974641695</td><td>checkout</td><td>List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1)</td></tr><tr><td>UA000000106488761</td><td>1593608056973513</td><td>shipping_info</td><td>List(null, M_PREM_Q, Premium Queen Mattress, 1795.0, 1795.0, 1)</td></tr><tr><td>UA000000106513250</td><td>1593612145817971</td><td>cart</td><td>List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1)</td></tr><tr><td>UA000000106530934</td><td>1593617743761830</td><td>cc_info</td><td>List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1)</td></tr><tr><td>UA000000106520932</td><td>1593805531448682</td><td>cc_info</td><td>List(NEWBED10, M_PREM_Q, Premium Queen Mattress, 1615.5, 1795.0, 1)</td></tr><tr><td>UA000000106505791</td><td>1593609987798063</td><td>add_item</td><td>List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1)</td></tr><tr><td>UA000000106509088</td><td>1593615004570770</td><td>finalize</td><td>List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1)</td></tr><tr><td>UA000000106554967</td><td>1593619947136352</td><td>add_item</td><td>List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1)</td></tr><tr><td>UA000000106526202</td><td>1593614227760804</td><td>add_item</td><td>List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1)</td></tr><tr><td>UA000000106459541</td><td>1593587811797459</td><td>shipping_info</td><td>List(null, M_PREM_T, Premium Twin Mattress, 1095.0, 1095.0, 1)</td></tr><tr><td>UA000000106508033</td><td>1593610581728978</td><td>checkout</td><td>List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1)</td></tr><tr><td>UA000000106464658</td><td>1593595892983249</td><td>shipping_info</td><td>List(null, M_STAN_T, Standard Twin Mattress, 1190.0, 595.0, 2)</td></tr><tr><td>UA000000106506214</td><td>1593615611683389</td><td>shipping_info</td><td>List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1)</td></tr><tr><td>UA000000106460839</td><td>1593589688074699</td><td>cc_info</td><td>List(null, M_STAN_K ...

# %% [markdown]
# ## Collect Arrays
#
# The **`collect_set`** function can collect unique values for a field, including fields within arrays.
#
# The **`flatten`** function allows multiple arrays to be combined into a single array.
#
# The **`array_distinct`** function removes duplicate elements from an array.
#
# Here, we combine these queries to create a simple table that shows the unique collection of actions and the items in a user's cart.

# %%
# %sql
SELECT user_id,
  collect_set(event_name) AS event_history,
  array_distinct(flatten(collect_set(items.item_id))) AS cart_history
FROM events
GROUP BY user_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>event_history</th><th>cart_history</th></tr></thead><tbody><tr><td>UA000000102368951</td><td>List(checkout, cart, add_item, cc_info, finalize, register, shipping_info, mattresses)</td><td>List(M_PREM_K, M_STAN_F)</td></tr><tr><td>UA000000102377152</td><td>List(mattresses, cart, cc_info, finalize, register, shipping_info, checkout)</td><td>List(M_STAN_F)</td></tr><tr><td>UA000000102388362</td><td>List(finalize)</td><td>List(M_STAN_F, P_DOWN_S)</td></tr><tr><td>UA000000102392998</td><td>List(mattresses)</td><td>List()</td></tr><tr><td>UA000000102435405</td><td>List(checkout, cart, add_item, cc_info, guest, finalize, shipping_info, mattresses)</td><td>List(M_STAN_T)</td></tr><tr><td>UA000000102462564</td><td>List(mattresses, login, add_item, cart, cc_info, finalize, shipping_info, checkout)</td><td>List(M_STAN_T, P_FOAM_S, M_STAN_Q)</td></tr><tr><td>UA000000102464478</td><td>List(mattresses, cart, add_item, cc_info, guest, finalize, shipping_info, checkout)</td><td>List(M_PREM_T, P_FOAM_S)</td></tr><tr><td>UA000000102477568</td><td>List(mattresses, cart, add_item, cc_info, finalize, register, shipping_info, checkout)</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102515405</td><td>List(cc_info, finalize, register, shipping_info, checkout)</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102516945</td><td>List(mattresses, cart, add_item, cc_info, guest, finalize, shipping_info, checkout)</td><td>List(M_PREM_F)</td></tr><tr><td>UA000000102525768</td><td>List(checkout, cart, add_item, cc_info, finalize, register, shipping_info, mattresses)</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102535599</td><td>List(checkout, cart, add_item, cc_info, guest, finalize, shipping_info, mattresses)</td><td>List(M_STAN_T)</td></tr><tr><td>UA000000102565521</td><td>List(checkout, cart, cc_info, guest, finalize, shipping_info, mattresses)</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102586164</td><td>List(mattresses, cart, add_item, cc_info, guest, finalize, shipping_info, checkout)</td><td>List(M_STAN_Q)</td></tr><tr><td>UA000000102589362</td><td>List(mattresses, cart, add_item, cc_info, guest, finalize, shipping_info, checkout)</td><td>List(M_STAN_K)</td></tr><tr><td>UA000000102590974</td><td>List(checkout, cart, add_item, cc_info, guest, finalize, shipping_info, mattresses)</td><td>List(M_STAN_Q, P_DOWN_S)</td></tr><tr><td>UA000000102593679</td><td>List(mattresses, cart, add_item, cc_info, guest, finalize, shipping_info, checkout)</td><td>List(P_DOWN_S)</td></tr><tr><td>UA000000102598657</td><td>List(mattresses, cart, add_item, cc_info, guest, finalize, shipping_info, checkout)</td><td>List(M_STAN_T)</td></tr><tr><td>UA000000102603122</td><td>List(mattresses, cart, add_item, cc_info, guest, finalize, shipping_info, checkout)</td><td>List(M_STAN_T)</td></tr><tr><td>UA000000102607675</td><td>List(checkout, cart, cc_info, guest, finalize, shipping_info, mattresses)</td><td>List(M_STAN_F)</td></tr><tr><td>UA000000102609265</td><td>List(add_item, mattresses)</td><td>List(M_STAN_F)</td></tr><tr><td>UA000000102610522</td><td>List(mattresses, cart, add_item, cc_info, guest, finalize, shipping_info, checkout)</td><td>List(M_STAN_F)</td></tr><tr><td>UA000000102615836</td><td>List(mattresses, cart, add_item, cc_info, guest, finalize, shipping_info, checkout)</td><td>List(P_FOAM_S)</td></tr><tr><td>UA000000102618137</td><td>List(mattresses, cart, add_item, cc_info, finalize, register, shipping_info, checkout)</td><td>List(M_STAN_F)</td></tr><tr><td>UA000000102640613</td><td>List(mattresses, cart, add_item, cc_info, guest, finalize, shipping_info, checkout)</td><td>List(M_STAN_T)</td></tr><tr><td>UA000000102662008</td><td>List(mattresses, cart, add_item, cc_info, guest, finalize, shipping_info, checkout)</td><td>List(M_STAN_K)</td></tr><tr><td>UA000000102677427</td><td>List(mattresses, login, add_item, cart, cc_info, fina ...

# %% [markdown]
# ## Join Tables
#
# Spark SQL supports standard join operations (inner, outer, left, right, anti, cross, semi).
#
# Here we chain a join with a lookup table to an **`explode`** operation to grab the standard printed item name.

# %%
# %sql
CREATE OR REPLACE VIEW sales_enriched AS
SELECT *
FROM (
  SELECT *, explode(items) AS item 
  FROM sales) a
INNER JOIN item_lookup b
ON a.item.item_id = b.item_id;

SELECT * FROM sales_enriched
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>email</th><th>transaction_timestamp</th><th>total_item_quantity</th><th>purchase_revenue_in_usd</th><th>unique_items</th><th>items</th><th>item</th><th>item_id</th><th>name</th><th>price</th></tr></thead><tbody><tr><td>285712</td><td>wbrown@gonzales-miranda.com</td><td>1592521889512254</td><td>2</td><td>1071.0</td><td>1</td><td>List(List(NEWBED10, M_STAN_T, Standard Twin Mattress, 1071.0, 595.0, 2))</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 1071.0, 595.0, 2)</td><td>M_STAN_T</td><td>Standard Twin Mattress</td><td>595.0</td></tr><tr><td>277921</td><td>campbellkatrina@phillips-duarte.com</td><td>1592458670364116</td><td>1</td><td>850.5</td><td>1</td><td>List(List(NEWBED10, M_STAN_F, Standard Full Mattress, 850.5, 945.0, 1))</td><td>List(NEWBED10, M_STAN_F, Standard Full Mattress, 850.5, 945.0, 1)</td><td>M_STAN_F</td><td>Standard Full Mattress</td><td>945.0</td></tr><tr><td>274566</td><td>gregorytorres@meyer.com</td><td>1592419954844631</td><td>1</td><td>535.5</td><td>1</td><td>List(List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1))</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td><td>M_STAN_T</td><td>Standard Twin Mattress</td><td>595.0</td></tr><tr><td>257606</td><td>ryanolson@brooks.com</td><td>1592213705353885</td><td>2</td><td>1754.0</td><td>2</td><td>List(List(null, M_PREM_F, Premium Full Mattress, 1695.0, 1695.0, 1), List(null, P_FOAM_S, Standard Foam Pillow, 59.0, 59.0, 1))</td><td>List(null, M_PREM_F, Premium Full Mattress, 1695.0, 1695.0, 1)</td><td>M_PREM_F</td><td>Premium Full Mattress</td><td>1695.0</td></tr><tr><td>257606</td><td>ryanolson@brooks.com</td><td>1592213705353885</td><td>2</td><td>1754.0</td><td>2</td><td>List(List(null, M_PREM_F, Premium Full Mattress, 1695.0, 1695.0, 1), List(null, P_FOAM_S, Standard Foam Pillow, 59.0, 59.0, 1))</td><td>List(null, P_FOAM_S, Standard Foam Pillow, 59.0, 59.0, 1)</td><td>P_FOAM_S</td><td>Standard Foam Pillow</td><td>59.0</td></tr><tr><td>257628</td><td>kimberly68@mcpherson.net</td><td>1592214238807084</td><td>1</td><td>1045.0</td><td>1</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1))</td><td>List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1)</td><td>M_STAN_Q</td><td>Standard Queen Mattress</td><td>1045.0</td></tr><tr><td>289539</td><td>levans13@hotmail.com</td><td>1592572270401950</td><td>2</td><td>2016.0</td><td>2</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1), List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1))</td><td>List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1)</td><td>M_STAN_K</td><td>Standard King Mattress</td><td>1195.0</td></tr><tr><td>289539</td><td>levans13@hotmail.com</td><td>1592572270401950</td><td>2</td><td>2016.0</td><td>2</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1), List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1))</td><td>List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1)</td><td>M_STAN_Q</td><td>Standard Queen Mattress</td><td>1045.0</td></tr><tr><td>257794</td><td>anthonylopez@gmail.com</td><td>1592218840420069</td><td>1</td><td>1045.0</td><td>1</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1))</td><td>List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1)</td><td>M_STAN_Q</td><td>Standard Queen Mattress</td><td>1045.0</td></tr><tr><td>257918</td><td>wlarson@sanchez.info</td><td>1592221370370320</td><td>1</td><td>1695.0</td><td>1</td><td>List(List(null, M_PREM_F, Premium Full Mattress, 1695.0, 1695.0, 1))</td><td>List(null, M_PREM_F, Premium Full Mattress, 1695.0, 1695.0, 1)</td><td>M_PREM_F</td><td>Premium Full Mattress</td><td>1695.0</td></tr><tr><td>257798</td><td>hernandezjohnny@ball.com</td><td>1592218929139881</td><td>1</td><td> ...

# %% [markdown]
# ## Set Operators
# Spark SQL supports **`UNION`**, **`MINUS`**, and **`INTERSECT`** set operators.
#
# **`UNION`** returns the collection of two queries.
#
# The query below returns the same results as if we inserted our **`new_events_final`** into the **`events`** table.

# %%
# %sql
SELECT * FROM events 
UNION 
SELECT * FROM new_events_final
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device</th><th>ecommerce</th><th>event_name</th><th>event_previous_timestamp</th><th>event_timestamp</th><th>geo</th><th>items</th><th>traffic_source</th><th>user_first_touch_timestamp</th><th>user_id</th></tr></thead><tbody><tr><td>Android</td><td>List(null, null, null)</td><td>delivery</td><td>1593608889319762</td><td>1593608892119521</td><td>List(La Habra, CA)</td><td>List()</td><td>google</td><td>1593607831910185</td><td>UA000000106497002</td></tr><tr><td>macOS</td><td>List(null, null, null)</td><td>main</td><td>null</td><td>1593614356805317</td><td>List(San Antonio, TX)</td><td>List()</td><td>facebook</td><td>1593614356805317</td><td>UA000000106526891</td></tr><tr><td>Chrome OS</td><td>List(null, null, null)</td><td>warranty</td><td>1593601464446537</td><td>1593601767237755</td><td>List(Salem, MA)</td><td>List()</td><td>instagram</td><td>1593601435427348</td><td>UA000000106477539</td></tr><tr><td>iOS</td><td>List(null, null, null)</td><td>main</td><td>null</td><td>1593591162184972</td><td>List(Flagstaff, AZ)</td><td>List()</td><td>youtube</td><td>1593591162184972</td><td>UA000000106462846</td></tr><tr><td>Android</td><td>List(null, null, null)</td><td>main</td><td>null</td><td>1593618487291912</td><td>List(Frisco, TX)</td><td>List()</td><td>google</td><td>1593618487291912</td><td>UA000000106549974</td></tr><tr><td>Windows</td><td>List(null, null, null)</td><td>main</td><td>null</td><td>1593601400346620</td><td>List(New York, NY)</td><td>List()</td><td>facebook</td><td>1593601400346620</td><td>UA000000106477460</td></tr><tr><td>macOS</td><td>List(null, null, null)</td><td>original</td><td>1593597828746115</td><td>1593597836033567</td><td>List(New York, NY)</td><td>List()</td><td>direct</td><td>1593597828746115</td><td>UA000000106470396</td></tr><tr><td>Android</td><td>List(null, null, null)</td><td>add_item</td><td>1593614267924114</td><td>1593614767785568</td><td>List(Bristol, CT)</td><td>List(List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1))</td><td>google</td><td>1593614267924114</td><td>UA000000106526430</td></tr><tr><td>Chrome OS</td><td>List(null, null, null)</td><td>add_item</td><td>1593598140273117</td><td>1593598612510988</td><td>List(Concord, NC)</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1))</td><td>facebook</td><td>1593598140273117</td><td>UA000000106470943</td></tr><tr><td>Android</td><td>List(null, null, null)</td><td>add_item</td><td>1593602059232593</td><td>1593602550671812</td><td>List(New York, NY)</td><td>List(List(null, P_DOWN_S, Standard Down Pillow, 119.0, 119.0, 1))</td><td>instagram</td><td>1593602010363455</td><td>UA000000106478945</td></tr><tr><td>Windows</td><td>List(null, null, null)</td><td>email_coupon</td><td>1593602190369456</td><td>1593602816821275</td><td>List(Raleigh, NC)</td><td>List()</td><td>google</td><td>1593602190369456</td><td>UA000000106479378</td></tr><tr><td>Android</td><td>List(null, null, null)</td><td>cart</td><td>1593616705048775</td><td>1593617407227274</td><td>List(Charlotte, NC)</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>email</td><td>1593614414174086</td><td>UA000000106527210</td></tr><tr><td>Android</td><td>List(null, null, null)</td><td>add_item</td><td>1593595595984555</td><td>1593595620017592</td><td>List(De Kalb, TX)</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1))</td><td>instagram</td><td>1593595391984879</td><td>UA000000106466918</td></tr><tr><td>Windows</td><td>List(null, null, null)</td><td>pillows</td><td>1593615949576992</td><td>1593616418970242</td><td>List(New York, NY)</td><td>List()</td><td>google</td><td>1593615949576992</td><td>UA000000106535594</td></tr><tr><td>Chrome OS</td><td>List(null, null, null)</td><td>warranty</td><td>1593601768244399</td><td>1593601811430605</td><td>List(Portland, OR)</td><td>List()</td><td>goo ...

# %% [markdown]
# **`INTERSECT`** returns all rows found in both relations.

# %%
# %sql
SELECT * FROM events 
INTERSECT 
SELECT * FROM new_events_final
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device</th><th>ecommerce</th><th>event_name</th><th>event_previous_timestamp</th><th>event_timestamp</th><th>geo</th><th>items</th><th>traffic_source</th><th>user_first_touch_timestamp</th><th>user_id</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# The above query returns no results because our two datasets have no values in common.
#
# **`MINUS`** returns all the rows found in one dataset but not the other; we'll skip executing this here as our previous query demonstrates we have no values in common.

# %% [markdown]
# ## Pivot Tables
# The **`PIVOT`** clause is used for data perspective. We can get the aggregated values based on specific column values, which will be turned to multiple columns used in **`SELECT`** clause. The **`PIVOT`** clause can be specified after the table name or subquery.
#
# **`SELECT * FROM ()`**: The **`SELECT`** statement inside the parentheses is the input for this table.
#
# **`PIVOT`**: The first argument in the clause is an aggregate function and the column to be aggregated. Then, we specify the pivot column in the **`FOR`** subclause. The **`IN`** operator contains the pivot column values.
#
# Here we use **`PIVOT`** to create a new **`transactions`** table that flattens out the information contained in the **`sales`** table.
#
# This flattened data format can be useful for dashboarding, but also useful for applying machine learning algorithms for inference or prediction.

# %%
# %sql
CREATE OR REPLACE TABLE transactions AS

SELECT * FROM (
  SELECT
    email,
    order_id,
    transaction_timestamp,
    total_item_quantity,
    purchase_revenue_in_usd,
    unique_items,
    item.item_id AS item_id,
    item.quantity AS quantity
  FROM sales_enriched
) PIVOT (
  sum(quantity) FOR item_id in (
    'P_FOAM_K',
    'M_STAN_Q',
    'P_FOAM_S',
    'M_PREM_Q',
    'M_STAN_F',
    'M_STAN_T',
    'M_PREM_K',
    'M_PREM_F',
    'M_STAN_K',
    'M_PREM_T',
    'P_DOWN_S',
    'P_DOWN_K'
  )
);

SELECT * FROM transactions
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>email</th><th>order_id</th><th>transaction_timestamp</th><th>total_item_quantity</th><th>purchase_revenue_in_usd</th><th>unique_items</th><th>P_FOAM_K</th><th>M_STAN_Q</th><th>P_FOAM_S</th><th>M_PREM_Q</th><th>M_STAN_F</th><th>M_STAN_T</th><th>M_PREM_K</th><th>M_PREM_F</th><th>M_STAN_K</th><th>M_PREM_T</th><th>P_DOWN_S</th><th>P_DOWN_K</th></tr></thead><tbody><tr><td>ewalker@jordan-johnson.com</td><td>280515</td><td>1592493134477009</td><td>1</td><td>1195.0</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1</td><td>null</td><td>null</td><td>null</td></tr><tr><td>james27@hotmail.com</td><td>413849</td><td>1593468897891582</td><td>1</td><td>59.0</td><td>1</td><td>null</td><td>null</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>cassie17@medina-anderson.com</td><td>445523</td><td>1593713036444518</td><td>2</td><td>2074.0</td><td>2</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>angela76@yahoo.com</td><td>291471</td><td>1592582917701512</td><td>1</td><td>945.0</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>gromero25@hotmail.com</td><td>458773</td><td>1593807106272431</td><td>2</td><td>2054.0</td><td>2</td><td>null</td><td>null</td><td>1</td><td>null</td><td>null</td><td>null</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>brayjose@carter.com</td><td>455266</td><td>1593791115255038</td><td>1</td><td>1195.0</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1</td><td>null</td><td>null</td><td>null</td></tr><tr><td>wattsmarilyn@gmail.com</td><td>342102</td><td>1592934506123227</td><td>1</td><td>1195.0</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1</td><td>null</td><td>null</td><td>null</td></tr><tr><td>tbrown21@gmail.com</td><td>288049</td><td>1592556531385950</td><td>1</td><td>107.10000000000001</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1</td><td>null</td></tr><tr><td>cynthia7765@hotmail.com</td><td>419668</td><td>1593528333512589</td><td>1</td><td>1995.0</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>qpeterson@gmail.com</td><td>261103</td><td>1592246766873852</td><td>1</td><td>1195.0</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1</td><td>null</td><td>null</td><td>null</td></tr><tr><td>brenda77@fisher.info</td><td>349194</td><td>1592985196598278</td><td>1</td><td>535.5</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>ltaylor70@gmail.com</td><td>290910</td><td>1592580311473995</td><td>1</td><td>595.0</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>sharonmorris@yahoo.com</td><td>329024</td><td>1592843145464065</td><td>2</td><td>1990.0</td><td>2</td><td>null</td><td>1</td><td>null</td><td>null</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>fitzgeraldcraig@gmail.com</td><td>315115< ...

# %% [markdown]
# ## Higher Order Functions
# Higher order functions in Spark SQL allow you to work directly with complex data types. When working with hierarchical data, records are frequently stored as array or map type objects. Higher-order functions allow you to transform data while preserving the original structure.
#
# Higher order functions include:
# - **`FILTER`** filters an array using the given lambda function.
# - **`EXIST`** tests whether a statement is true for one or more elements in an array.
# - **`TRANSFORM`** uses the given lambda function to transform all elements in an array.
# - **`REDUCE`** takes two lambda functions to reduce the elements of an array to a single value by merging the elements into a buffer, and the apply a finishing function on the final buffer.

# %% [markdown]
# ## Filter
# Remove items that are not king-sized from all records in our **`items`** column. We can use the **`FILTER`** function to create a new column that excludes that value from each array.
#
# **`FILTER (items, i -> i.item_id LIKE "%K") AS king_items`**
#
# In the statement above:
# - **`FILTER`** : the name of the higher-order function <br>
# - **`items`** : the name of our input array <br>
# - **`i`** : the name of the iterator variable. You choose this name and then use it in the lambda function. It iterates over the array, cycling each value into the function one at a time.<br>
# - **`->`** :  Indicates the start of a function <br>
# - **`i.item_id LIKE "%K"`** : This is the function. Each value is checked to see if it ends with the capital letter K. If it is, it gets filtered into the new column, **`king_items`**

# %%
# %sql
-- filter for sales of only king sized items
SELECT
  order_id,
  items,
  FILTER (items, i -> i.item_id LIKE "%K") AS king_items
FROM sales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>items</th><th>king_items</th></tr></thead><tbody><tr><td>285712</td><td>List(List(NEWBED10, M_STAN_T, Standard Twin Mattress, 1071.0, 595.0, 2))</td><td>List()</td></tr><tr><td>277921</td><td>List(List(NEWBED10, M_STAN_F, Standard Full Mattress, 850.5, 945.0, 1))</td><td>List()</td></tr><tr><td>274566</td><td>List(List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1))</td><td>List()</td></tr><tr><td>257606</td><td>List(List(null, M_PREM_F, Premium Full Mattress, 1695.0, 1695.0, 1), List(null, P_FOAM_S, Standard Foam Pillow, 59.0, 59.0, 1))</td><td>List()</td></tr><tr><td>257628</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1))</td><td>List()</td></tr><tr><td>289539</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1), List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1))</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1))</td></tr><tr><td>257794</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1))</td><td>List()</td></tr><tr><td>257918</td><td>List(List(null, M_PREM_F, Premium Full Mattress, 1695.0, 1695.0, 1))</td><td>List()</td></tr><tr><td>257798</td><td>List(List(null, M_PREM_F, Premium Full Mattress, 1695.0, 1695.0, 1))</td><td>List()</td></tr><tr><td>258127</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>257923</td><td>List(List(null, M_PREM_Q, Premium Queen Mattress, 1795.0, 1795.0, 1))</td><td>List()</td></tr><tr><td>258155</td><td>List(List(null, M_PREM_Q, Premium Queen Mattress, 1795.0, 1795.0, 1))</td><td>List()</td></tr><tr><td>258115</td><td>List(List(null, M_PREM_F, Premium Full Mattress, 1695.0, 1695.0, 1))</td><td>List()</td></tr><tr><td>278572</td><td>List(List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1))</td><td>List()</td></tr><tr><td>298991</td><td>List(List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1))</td><td>List()</td></tr><tr><td>258561</td><td>List(List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1))</td><td>List()</td></tr><tr><td>275792</td><td>List(List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1))</td><td>List()</td></tr><tr><td>258384</td><td>List(List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1))</td><td>List()</td></tr><tr><td>281527</td><td>List(List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1))</td><td>List()</td></tr><tr><td>258653</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>259567</td><td>List(List(null, M_STAN_T, Standard Twin Mattress, 1190.0, 595.0, 2))</td><td>List()</td></tr><tr><td>259233</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1))</td><td>List()</td></tr><tr><td>288311</td><td>List(List(NEWBED10, M_PREM_Q, Premium Queen Mattress, 1615.5, 1795.0, 1), List(NEWBED10, P_FOAM_K, King Foam Pillow, 71.10000000000001, 79.0, 1))</td><td>List(List(NEWBED10, P_FOAM_K, King Foam Pillow, 71.10000000000001, 79.0, 1))</td></tr><tr><td>259306</td><td>List(List(null, M_STAN_T, Standard Twin Mattress, 1190.0, 595.0, 2))</td><td>List()</td></tr><tr><td>284378</td><td>List(List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1))</td><td>List()</td></tr><tr><td>259273</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1))</td><td>List()</td></tr><tr><td>277955</td><td>List(List(NEWBED10, M_STAN_F, Standard Full Mattress, 850.5, 945.0, 1), List(NEWBED10, P_FOAM_S, Standard Foam Pillow, 53.1, 59.0, 1))</td><td>List()</td></tr><tr><td>277614</td><td>List(List(NEWBED10, M_PREM_K, Premium King Mattress, 1795.5, 1995.0, 1))</td><td>L ...

# %% [markdown]
# You may write a filter that produces a lot of empty arrays in the created column. When that happens, it can be useful to use a **`WHERE`** clause to show only non-empty array values in the returned column.
#
# In this example, we accomplish that by using a subquery (a query within a query). They are useful for performing an operation in multiple steps. In this case, we're using it to create the named column that we will use with a **`WHERE`** clause.

# %%
# %sql
CREATE OR REPLACE TEMP VIEW king_size_sales AS

SELECT order_id, king_items
FROM (
  SELECT
    order_id,
    FILTER (items, i -> i.item_id LIKE "%K") AS king_items
  FROM sales)
WHERE size(king_items) > 0;
  
SELECT * FROM king_size_sales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>king_items</th></tr></thead><tbody><tr><td>289539</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1))</td></tr><tr><td>258127</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>258653</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>288311</td><td>List(List(NEWBED10, P_FOAM_K, King Foam Pillow, 71.10000000000001, 79.0, 1))</td></tr><tr><td>277614</td><td>List(List(NEWBED10, M_PREM_K, Premium King Mattress, 1795.5, 1995.0, 1))</td></tr><tr><td>259947</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>260236</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>260228</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>261148</td><td>List(List(null, M_PREM_K, Premium King Mattress, 1995.0, 1995.0, 1))</td></tr><tr><td>261103</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>261454</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>261789</td><td>List(List(null, M_PREM_K, Premium King Mattress, 1995.0, 1995.0, 1))</td></tr><tr><td>262347</td><td>List(List(null, P_FOAM_K, King Foam Pillow, 79.0, 79.0, 1))</td></tr><tr><td>278190</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1))</td></tr><tr><td>263247</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>278118</td><td>List(List(NEWBED10, M_PREM_K, Premium King Mattress, 1795.5, 1995.0, 1))</td></tr><tr><td>264223</td><td>List(List(null, M_PREM_K, Premium King Mattress, 1995.0, 1995.0, 1))</td></tr><tr><td>264439</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>289051</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1))</td></tr><tr><td>265280</td><td>List(List(null, M_PREM_K, Premium King Mattress, 1995.0, 1995.0, 1))</td></tr><tr><td>299643</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1))</td></tr><tr><td>266689</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>304926</td><td>List(List(NEWBED10, P_DOWN_K, King Down Pillow, 143.1, 159.0, 1))</td></tr><tr><td>267617</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>270353</td><td>List(List(null, M_PREM_K, Premium King Mattress, 1995.0, 1995.0, 1))</td></tr><tr><td>285710</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1))</td></tr><tr><td>271184</td><td>List(List(null, M_PREM_K, Premium King Mattress, 1995.0, 1995.0, 1))</td></tr><tr><td>286150</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1))</td></tr><tr><td>304329</td><td>List(List(NEWBED10, M_PREM_K, Premium King Mattress, 1795.5, 1995.0, 1))</td></tr><tr><td>272478</td><td>List(List(null, P_FOAM_K, King Foam Pillow, 79.0, 79.0, 1))</td></tr><tr><td>272386</td><td>List(List(null, P_DOWN_K, King Down Pillow, 159.0, 159.0, 1))</td></tr><tr><td>297808</td><td>List(List(NEWBED10, M_PREM_K, Premium King Mattress, 1795.5, 1995.0, 1))</td></tr><tr><td>273688</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>274218</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>274864</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>274396</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td></tr><tr><td>313976</td><td>List(List(NEWBED10, M_PREM_K, Premium King Mattress, 1795.5, 1995.0, 1))</td></tr><tr><td>275674</td><td>List(List(null, M_STAN_K ...

# %% [markdown]
# ## Transform
# Built-in functions are designed to operate on a single, simple data type within a cell; they cannot process array values. **`TRANSFORM`** can be particularly useful when you want to apply an existing function to each element in an array.
#
# Compute the total revenue from king-sized items per order.
#
# **`TRANSFORM(king_items, k -> CAST(k.item_revenue_in_usd * 100 AS INT)) AS item_revenues`**
#
# In the statement above, for each value in the input array, we extract the item's revenue value, multiply it by 100, and cast the result to integer. Note that we're using the same kind as references as in the previous command, but we name the iterator with a new variable, **`k`**.

# %%
# %sql
-- get total revenue from king items per order
CREATE OR REPLACE TEMP VIEW king_item_revenues AS

SELECT
  order_id,
  king_items,
  TRANSFORM (
    king_items,
    k -> CAST(k.item_revenue_in_usd * 100 AS INT)
  ) AS item_revenues
FROM king_size_sales;

SELECT * FROM king_item_revenues
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>king_items</th><th>item_revenues</th></tr></thead><tbody><tr><td>289539</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1))</td><td>List(107550)</td></tr><tr><td>258127</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>List(119500)</td></tr><tr><td>258653</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>List(119500)</td></tr><tr><td>288311</td><td>List(List(NEWBED10, P_FOAM_K, King Foam Pillow, 71.10000000000001, 79.0, 1))</td><td>List(7110)</td></tr><tr><td>277614</td><td>List(List(NEWBED10, M_PREM_K, Premium King Mattress, 1795.5, 1995.0, 1))</td><td>List(179550)</td></tr><tr><td>259947</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>List(119500)</td></tr><tr><td>260236</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>List(119500)</td></tr><tr><td>260228</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>List(119500)</td></tr><tr><td>261148</td><td>List(List(null, M_PREM_K, Premium King Mattress, 1995.0, 1995.0, 1))</td><td>List(199500)</td></tr><tr><td>261103</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>List(119500)</td></tr><tr><td>261454</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>List(119500)</td></tr><tr><td>261789</td><td>List(List(null, M_PREM_K, Premium King Mattress, 1995.0, 1995.0, 1))</td><td>List(199500)</td></tr><tr><td>262347</td><td>List(List(null, P_FOAM_K, King Foam Pillow, 79.0, 79.0, 1))</td><td>List(7900)</td></tr><tr><td>278190</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1))</td><td>List(107550)</td></tr><tr><td>263247</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>List(119500)</td></tr><tr><td>278118</td><td>List(List(NEWBED10, M_PREM_K, Premium King Mattress, 1795.5, 1995.0, 1))</td><td>List(179550)</td></tr><tr><td>264223</td><td>List(List(null, M_PREM_K, Premium King Mattress, 1995.0, 1995.0, 1))</td><td>List(199500)</td></tr><tr><td>264439</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>List(119500)</td></tr><tr><td>289051</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1))</td><td>List(107550)</td></tr><tr><td>265280</td><td>List(List(null, M_PREM_K, Premium King Mattress, 1995.0, 1995.0, 1))</td><td>List(199500)</td></tr><tr><td>299643</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1))</td><td>List(107550)</td></tr><tr><td>266689</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>List(119500)</td></tr><tr><td>304926</td><td>List(List(NEWBED10, P_DOWN_K, King Down Pillow, 143.1, 159.0, 1))</td><td>List(14310)</td></tr><tr><td>267617</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>List(119500)</td></tr><tr><td>270353</td><td>List(List(null, M_PREM_K, Premium King Mattress, 1995.0, 1995.0, 1))</td><td>List(199500)</td></tr><tr><td>285710</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1))</td><td>List(107550)</td></tr><tr><td>271184</td><td>List(List(null, M_PREM_K, Premium King Mattress, 1995.0, 1995.0, 1))</td><td>List(199500)</td></tr><tr><td>286150</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1))</td><td>List(107550)</td></tr><tr><td>304329</td><td>List(List(NEWBED10, M_PREM_K, Premium King Mattress, 1795.5, 1995.0, 1))</td><td>List(179550)</td></tr><tr><td>272478</td><td>List(List(null, P_FOAM_K, King Foam Pillow, 79.0, 79.0, 1))</td><td>List(7900)</td></tr><tr><td>272386</td><td>List(List(null, P_DOWN_K, King Down Pillow, 159.0, 159.0, 1))</td><td>List(15900)</td></tr> ...

# %% [markdown]
# ## Summary
# Spark SQL offers a comprehensive set of native functionality for interacting with and manipulating highly nested data.
#
# While some syntax for this functionality may be unfamiliar to SQL users, leveraging built-in functions like higher order functions can prevent SQL engineers from needing to rely on custom logic when dealing with highly complex data structures.

# %% [markdown]
# Run the following cell to delete the tables and files associated with this lesson.

# %%
# %python
DA.cleanup()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Dropping the database &#34;dbacademy_manujkumar_joshi_celebaltech_com_dewd_4_7&#34;
# Removing the working directory &#34;dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/4.7&#34;
# </div>

# %% [markdown]
# -sandbox
# &copy; 2022 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="https://help.databricks.com/">Support</a>
