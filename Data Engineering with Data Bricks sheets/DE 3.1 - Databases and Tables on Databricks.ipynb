# %% [markdown]
# -sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Databases and Tables on Databricks
# In this demonstration, you will create and explore databases and tables.
#
# ## Learning Objectives
# By the end of this lesson, you should be able to:
# * Use Spark SQL DDL to define databases and tables
# * Describe how the **`LOCATION`** keyword impacts the default storage directory
#
#
#
# **Resources**
# * <a href="https://docs.databricks.com/user-guide/tables.html" target="_blank">Databases and Tables - Databricks Docs</a>
# * <a href="https://docs.databricks.com/user-guide/tables.html#managed-and-unmanaged-tables" target="_blank">Managed and Unmanaged Tables</a>
# * <a href="https://docs.databricks.com/user-guide/tables.html#create-a-table-using-the-ui" target="_blank">Creating a Table with the UI</a>
# * <a href="https://docs.databricks.com/user-guide/tables.html#create-a-local-table" target="_blank">Create a Local Table</a>
# * <a href="https://spark.apache.org/docs/latest/sql-data-sources-load-save-functions.html#saving-to-persistent-tables" target="_blank">Saving to Persistent Tables</a>

# %% [markdown]
# ## Lesson Setup
# The following script clears out previous runs of this demo and configures some Hive variables that will be used in our SQL queries.

# %%
# %run ../Includes/Classroom-Setup-3.1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Python interpreter will be restarted.
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Skipping install to &#34;dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/source/dtavod&#34;, dataset already exists
# Creating the flight_delays dataset...(2 seconds / 1,391,579 records)
#
# Creating the flights dataset...(2 seconds / 1,391,579 records)
#
# Predefined Paths:
#   DA.paths.working_dir: dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.1
#   DA.paths.user_db:     dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.1/3_1.db
#   DA.paths.datasets:    dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/source/dtavod
#
# Setup completed in 5 seconds
# </div>

# %% [markdown]
# ## Using Hive Variables
#
# While not a pattern that is generally recommended in Spark SQL, this notebook will use some Hive variables to substitute in string values derived from the account email of the current user.
#
# The following cell demonstrates this pattern.

# %%
# %sql
SELECT "${da.db_name}" AS db_name,
       "${da.paths.working_dir}" AS working_dir
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>db_name</th><th>working_dir</th></tr></thead><tbody><tr><td>dbacademy_manujkumar_joshi_celebaltech_com_dewd_3_1</td><td>dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.1</td></tr></tbody></table></div>

# %% [markdown]
# Because you may be working in a shared workspace, this course uses variables derived from your username so the databases don't conflict with other users. Again, consider this use of Hive variables a hack for our lesson environment rather than a good practice for development.

# %% [markdown]
# # Databases
# Let's start by creating two databases:
# - One with no **`LOCATION`** specified
# - One with **`LOCATION`** specified

# %%
# %sql
CREATE DATABASE IF NOT EXISTS ${da.db_name}_default_location;
CREATE DATABASE IF NOT EXISTS ${da.db_name}_custom_location LOCATION '${da.paths.working_dir}/_custom_location.db';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Note that the location of the first database is in the default location under **`dbfs:/user/hive/warehouse/`** and that the database directory is the name of the database with the **`.db`** extension

# %%
# %sql
DESCRIBE DATABASE EXTENDED ${da.db_name}_default_location;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database_description_item</th><th>database_description_value</th></tr></thead><tbody><tr><td>Namespace Name</td><td>dbacademy_manujkumar_joshi_celebaltech_com_dewd_3_1_default_location</td></tr><tr><td>Comment</td><td></td></tr><tr><td>Location</td><td>dbfs:/user/hive/warehouse/dbacademy_manujkumar_joshi_celebaltech_com_dewd_3_1_default_location.db</td></tr><tr><td>Owner</td><td>root</td></tr><tr><td>Properties</td><td></td></tr></tbody></table></div>

# %% [markdown]
# Note that the location of the second database is in the directory specified after the **`LOCATION`** keyword.

# %%
# %sql
DESCRIBE DATABASE EXTENDED ${da.db_name}_custom_location;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database_description_item</th><th>database_description_value</th></tr></thead><tbody><tr><td>Namespace Name</td><td>dbacademy_manujkumar_joshi_celebaltech_com_dewd_3_1_custom_location</td></tr><tr><td>Comment</td><td></td></tr><tr><td>Location</td><td>dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.1/_custom_location.db</td></tr><tr><td>Owner</td><td>root</td></tr><tr><td>Properties</td><td></td></tr></tbody></table></div>

# %% [markdown]
# ### We will create a table in the database with default location and insert data.
#
# Note that the schema must be provided because there is no data from which to infer the schema.

# %%
# %sql
USE ${da.db_name}_default_location;

CREATE OR REPLACE TABLE managed_table_in_db_with_default_location (width INT, length INT, height INT);
INSERT INTO managed_table_in_db_with_default_location 
VALUES (3, 2, 1);
SELECT * FROM managed_table_in_db_with_default_location;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>width</th><th>length</th><th>height</th></tr></thead><tbody><tr><td>3</td><td>2</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# We can look at the extended table description to find the location (you'll need to scroll down in the results).

# %%
# %sql
DESCRIBE EXTENDED managed_table_in_db_with_default_location;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>width</td><td>int</td><td></td></tr><tr><td>length</td><td>int</td><td></td></tr><tr><td>height</td><td>int</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Partitioning</td><td></td><td></td></tr><tr><td>Not partitioned</td><td></td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>spark_catalog</td><td></td></tr><tr><td>Database</td><td>dbacademy_manujkumar_joshi_celebaltech_com_dewd_3_1_default_location</td><td></td></tr><tr><td>Table</td><td>managed_table_in_db_with_default_location</td><td></td></tr><tr><td>Location</td><td>dbfs:/user/hive/warehouse/dbacademy_manujkumar_joshi_celebaltech_com_dewd_3_1_default_location.db/managed_table_in_db_with_default_location</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %% [markdown]
# ### By default, managed tables in a database without the location specified will be created in the **`dbfs:/user/hive/warehouse/<database_name>.db/`** directory.
#
# We can see that, as expected, the data and metadata for our Delta Table are stored in that location.

# %%
# %python 
hive_root =  f"dbfs:/user/hive/warehouse"
db_name =    f"{DA.db_name}_default_location.db"
table_name = f"managed_table_in_db_with_default_location"

tbl_location = f"{hive_root}/{db_name}/{table_name}"
print(tbl_location)

files = dbutils.fs.ls(tbl_location)
display(files)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/user/hive/warehouse/dbacademy_manujkumar_joshi_celebaltech_com_dewd_3_1_default_location.db/managed_table_in_db_with_default_location
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/dbacademy_manujkumar_joshi_celebaltech_com_dewd_3_1_default_location.db/managed_table_in_db_with_default_location/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1658999609000</td></tr><tr><td>dbfs:/user/hive/warehouse/dbacademy_manujkumar_joshi_celebaltech_com_dewd_3_1_default_location.db/managed_table_in_db_with_default_location/part-00000-2dd9ac28-2fcb-40f7-a71f-562860cdbf04-c000.snappy.parquet</td><td>part-00000-2dd9ac28-2fcb-40f7-a71f-562860cdbf04-c000.snappy.parquet</td><td>1045</td><td>1658999608000</td></tr></tbody></table></div>

# %% [markdown]
# Drop the table.

# %%
# %sql
DROP TABLE managed_table_in_db_with_default_location;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# #### Note the table's directory and its log and data files are deleted. Only the database directory remains.

# %%
# %python 

db_location = f"{hive_root}/{db_name}"
print(db_location)
dbutils.fs.ls(db_location)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/user/hive/warehouse/dbacademy_manujkumar_joshi_celebaltech_com_dewd_3_1_default_location.db
# Out[11]: []</div>

# %% [markdown]
# ### We now create a table in  the database with custom location and insert data.
#
# Note that the schema must be provided because there is no data from which to infer the schema.

# %%
# %sql
USE ${da.db_name}_custom_location;

CREATE OR REPLACE TABLE managed_table_in_db_with_custom_location (width INT, length INT, height INT);
INSERT INTO managed_table_in_db_with_custom_location VALUES (3, 2, 1);
SELECT * FROM managed_table_in_db_with_custom_location;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>width</th><th>length</th><th>height</th></tr></thead><tbody><tr><td>3</td><td>2</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# Again, we'll look at the description to find the table location.

# %%
# %sql
DESCRIBE EXTENDED managed_table_in_db_with_custom_location;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>width</td><td>int</td><td></td></tr><tr><td>length</td><td>int</td><td></td></tr><tr><td>height</td><td>int</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Partitioning</td><td></td><td></td></tr><tr><td>Not partitioned</td><td></td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>spark_catalog</td><td></td></tr><tr><td>Database</td><td>dbacademy_manujkumar_joshi_celebaltech_com_dewd_3_1_custom_location</td><td></td></tr><tr><td>Table</td><td>managed_table_in_db_with_custom_location</td><td></td></tr><tr><td>Location</td><td>dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.1/_custom_location.db/managed_table_in_db_with_custom_location</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %% [markdown]
# As expected, this managed table is created in the path specified with the **`LOCATION`** keyword during database creation. As such, the data and metadata for the table are persisted in a directory here.

# %%
# %python 

table_name = f"managed_table_in_db_with_custom_location"
tbl_location =   f"{DA.paths.working_dir}/_custom_location.db/{table_name}"
print(tbl_location)

files = dbutils.fs.ls(tbl_location)
display(files)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.1/_custom_location.db/managed_table_in_db_with_custom_location
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.1/_custom_location.db/managed_table_in_db_with_custom_location/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1658999614000</td></tr><tr><td>dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.1/_custom_location.db/managed_table_in_db_with_custom_location/part-00000-76a5a932-528f-4fb6-94cd-58ae7e62e22f-c000.snappy.parquet</td><td>part-00000-76a5a932-528f-4fb6-94cd-58ae7e62e22f-c000.snappy.parquet</td><td>1045</td><td>1658999613000</td></tr></tbody></table></div>

# %% [markdown]
# Let's drop the table.

# %%
# %sql
DROP TABLE managed_table_in_db_with_custom_location;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# #### Note the table's folder and the log file and data file are deleted.
#
# Only the database location remains

# %%
# %python 

db_location =   f"{DA.paths.working_dir}/_custom_location.db"
print(db_location)

dbutils.fs.ls(db_location)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.1/_custom_location.db
# Out[13]: []</div>

# %% [markdown]
# # Tables
# We will create an external (unmanaged) table from sample data.
#
# The data we are going to use are in CSV format. We want to create a Delta table with a **`LOCATION`** provided in the directory of our choice.

# %%
# %sql
USE ${da.db_name}_default_location;

CREATE OR REPLACE TEMPORARY VIEW temp_delays USING CSV OPTIONS (
  path = '${da.paths.working_dir}/flights/departuredelays.csv',
  header = "true",
  mode = "FAILFAST" -- abort file parsing with a RuntimeException if any malformed lines are encountered
);
CREATE OR REPLACE TABLE external_table LOCATION '${da.paths.working_dir}/external_table' AS
  SELECT * FROM temp_delays;

SELECT * FROM external_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>delay</th><th>distance</th><th>origin</th><th>destination</th></tr></thead><tbody><tr><td>01011245</td><td>6</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01020600</td><td>-8</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01021245</td><td>-2</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01020605</td><td>-4</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01031245</td><td>-4</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01030605</td><td>0</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01041243</td><td>10</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01040605</td><td>28</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01051245</td><td>88</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01050605</td><td>9</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01061215</td><td>-6</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01061725</td><td>69</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01061230</td><td>0</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01060625</td><td>-3</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01070600</td><td>0</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01071725</td><td>0</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01071230</td><td>0</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01070625</td><td>0</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01071219</td><td>0</td><td>569</td><td>ABE</td><td>ORD</td></tr><tr><td>01080600</td><td>0</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01081230</td><td>33</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01080625</td><td>1</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01080607</td><td>5</td><td>569</td><td>ABE</td><td>ORD</td></tr><tr><td>01081219</td><td>54</td><td>569</td><td>ABE</td><td>ORD</td></tr><tr><td>01091215</td><td>43</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01090600</td><td>151</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01091725</td><td>0</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01091230</td><td>-4</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01090625</td><td>8</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01091219</td><td>83</td><td>569</td><td>ABE</td><td>ORD</td></tr><tr><td>01101215</td><td>-5</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01100600</td><td>-5</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01101725</td><td>7</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01101230</td><td>-8</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01100625</td><td>52</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01101219</td><td>0</td><td>569</td><td>ABE</td><td>ORD</td></tr><tr><td>01111215</td><td>127</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01110600</td><td>-9</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01110625</td><td>-4</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01121215</td><td>-5</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01121725</td><td>-1</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01131215</td><td>14</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01130600</td><td>-7</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01131725</td><td>-6</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01131230</td><td>-13</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01130625</td><td>29</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01131219</td><td>-8</td><td>569</td><td>ABE</td><td>ORD</td></tr><tr><td>01140600</td><td>-9</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01141725</td><td>-9</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01141230</td><td>-8</td><td>369</td><td>ABE</td><td>DTW</td></tr><tr><td>01140625</td><td>-5</td><td>602</td><td>ABE</td><td>ATL</td></tr><tr><td>01141219</td><td>-10</td><td>569</td><td>ABE</td><td>ORD</td></tr><t ...

# %% [markdown]
# Let's note the location of the table's data in this lesson's working directory.

# %%
# %sql
DESCRIBE TABLE EXTENDED external_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>date</td><td>string</td><td></td></tr><tr><td>delay</td><td>string</td><td></td></tr><tr><td>distance</td><td>string</td><td></td></tr><tr><td>origin</td><td>string</td><td></td></tr><tr><td>destination</td><td>string</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Partitioning</td><td></td><td></td></tr><tr><td>Not partitioned</td><td></td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>spark_catalog</td><td></td></tr><tr><td>Database</td><td>dbacademy_manujkumar_joshi_celebaltech_com_dewd_3_1_default_location</td><td></td></tr><tr><td>Table</td><td>external_table</td><td></td></tr><tr><td>Location</td><td>dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.1/external_table</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2,external=true]</td><td></td></tr></tbody></table></div>

# %% [markdown]
# Now, we drop the table.

# %%
# %sql
DROP TABLE external_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# The table definition no longer exists in the metastore, but the underlying data remain intact.

# %%
# %python 
tbl_path = f"{DA.paths.working_dir}/external_table"
files = dbutils.fs.ls(tbl_path)
display(files)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.1/external_table/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1658999754000</td></tr><tr><td>dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.1/external_table/part-00000-5bb67393-f167-4c00-9e01-ea5ce21ac9aa-c000.snappy.parquet</td><td>part-00000-5bb67393-f167-4c00-9e01-ea5ce21ac9aa-c000.snappy.parquet</td><td>1814492</td><td>1658999752000</td></tr><tr><td>dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.1/external_table/part-00001-4b7407a1-0fee-4906-a270-72e770df9f17-c000.snappy.parquet</td><td>part-00001-4b7407a1-0fee-4906-a270-72e770df9f17-c000.snappy.parquet</td><td>1992029</td><td>1658999752000</td></tr><tr><td>dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.1/external_table/part-00002-40efc8bd-80df-45c9-96b6-a9679f5558ca-c000.snappy.parquet</td><td>part-00002-40efc8bd-80df-45c9-96b6-a9679f5558ca-c000.snappy.parquet</td><td>1949998</td><td>1658999752000</td></tr><tr><td>dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.1/external_table/part-00003-4516d586-0280-4541-b36e-a86d472f1fe6-c000.snappy.parquet</td><td>part-00003-4516d586-0280-4541-b36e-a86d472f1fe6-c000.snappy.parquet</td><td>983852</td><td>1658999752000</td></tr></tbody></table></div>

# %% [markdown]
# ## Clean up
# Drop both databases.

# %%
# %sql
DROP DATABASE ${da.db_name}_default_location CASCADE;
DROP DATABASE ${da.db_name}_custom_location CASCADE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Run the following cell to delete the tables and files associated with this lesson.

# %%
# %python 
DA.cleanup()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Removing the working directory &#34;dbfs:/user/manujkumar.joshi@celebaltech.com/dbacademy/dewd/3.1&#34;
# </div>

# %% [markdown]
# -sandbox
# &copy; 2022 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="https://help.databricks.com/">Support</a>
