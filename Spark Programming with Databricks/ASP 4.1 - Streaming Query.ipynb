# %% [markdown]
# -sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Streaming Query
#
# ##### Objectives
# 1. Build streaming DataFrames
# 1. Display streaming query results
# 1. Write streaming query results
# 1. Monitor streaming query
#
# ##### Classes
# - <a href="https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.streaming.DataStreamReader.html#pyspark.sql.streaming.DataStreamReader" target="_blank">DataStreamReader</a>
# - <a href="https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.streaming.DataStreamWriter.html#pyspark.sql.streaming.DataStreamWriter" target="_blank">DataStreamWriter</a>
# - <a href="https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.streaming.StreamingQuery.html#pyspark.sql.streaming.StreamingQuery" target="_blank">StreamingQuery</a>

# %%
# %run ./Includes/Classroom-Setup
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Finished setting up utiltity methods...
# Datasets mounted and student environment set up

# %% [markdown]
# ### Build streaming DataFrames
#
# Obtain an initial streaming DataFrame from a Parquet-format file source.

# %%
schema = "device STRING, ecommerce STRUCT<purchase_revenue_in_usd: DOUBLE, total_item_quantity: BIGINT, unique_items: BIGINT>, event_name STRING, event_previous_timestamp BIGINT, event_timestamp BIGINT, geo STRUCT<city: STRING, state: STRING>, items ARRAY<STRUCT<coupon: STRING, item_id: STRING, item_name: STRING, item_revenue_in_usd: DOUBLE, price_in_usd: DOUBLE, quantity: BIGINT>>, traffic_source STRING, user_first_touch_timestamp BIGINT, user_id STRING"

df = (spark
      .readStream
      .schema(schema)
      .option("maxFilesPerTrigger", 1)
      .parquet(eventsPath)
     )
df.isStreaming
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: True</div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device</th><th>ecommerce</th><th>event_name</th><th>event_previous_timestamp</th><th>event_timestamp</th><th>geo</th><th>items</th><th>traffic_source</th><th>user_first_touch_timestamp</th><th>user_id</th></tr></thead><tbody><tr><td>Windows</td><td>List(null, null, null)</td><td>add_item</td><td>1593604013418531</td><td>1593604166967411</td><td>List(Aurora, CO)</td><td>List(List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1))</td><td>google</td><td>1593603932991227</td><td>UA000000106484072</td></tr><tr><td>macOS</td><td>List(null, null, null)</td><td>guest</td><td>1593792667777632</td><td>1593793102376026</td><td>List(Atlanta, GA)</td><td>List(List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1), List(NEWBED10, P_FOAM_S, Standard Foam Pillow, 53.1, 59.0, 1), List(NEWBED10, M_PREM_Q, Premium Queen Mattress, 1615.5, 1795.0, 1))</td><td>email</td><td>1593606662775893</td><td>UA000000106492759</td></tr><tr><td>Linux</td><td>List(null, null, null)</td><td>main</td><td>null</td><td>1593610121403996</td><td>List(Uvalde, TX)</td><td>List()</td><td>google</td><td>1593610121403996</td><td>UA000000106506379</td></tr><tr><td>Android</td><td>List(null, null, null)</td><td>add_item</td><td>1593595457982777</td><td>1593595673594309</td><td>List(Houston, TX)</td><td>List(List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1))</td><td>email</td><td>1593595457982777</td><td>UA000000106466992</td></tr><tr><td>Android</td><td>List(null, null, null)</td><td>mattresses</td><td>null</td><td>1593577304912675</td><td>List(Reno, NV)</td><td>List()</td><td>instagram</td><td>1593577304912675</td><td>UA000000106458058</td></tr><tr><td>Windows</td><td>List(null, null, null)</td><td>main</td><td>null</td><td>1593609793654886</td><td>List(Phoenix, AZ)</td><td>List()</td><td>google</td><td>1593609793654886</td><td>UA000000106504949</td></tr><tr><td>Android</td><td>List(null, null, null)</td><td>pillows</td><td>null</td><td>1593619480937685</td><td>List(Chicago, IL)</td><td>List()</td><td>google</td><td>1593619480937685</td><td>UA000000106555879</td></tr><tr><td>macOS</td><td>List(null, null, null)</td><td>add_item</td><td>1593618267281779</td><td>1593618623952958</td><td>List(San Diego, CA)</td><td>List(List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1))</td><td>google</td><td>1593618267281779</td><td>UA000000106548706</td></tr><tr><td>Windows</td><td>List(null, null, null)</td><td>main</td><td>null</td><td>1593601683208285</td><td>List(Muskegon, MI)</td><td>List()</td><td>google</td><td>1593601683208285</td><td>UA000000106478125</td></tr><tr><td>Android</td><td>List(null, null, null)</td><td>add_item</td><td>1593594736126253</td><td>1593596897183596</td><td>List(Lancaster, OH)</td><td>List(List(null, M_PREM_T, Premium Twin Mattress, 2190.0, 1095.0, 2))</td><td>youtube</td><td>1593594736126253</td><td>UA000000106466114</td></tr><tr><td>Windows</td><td>List(null, null, null)</td><td>mattresses</td><td>null</td><td>1593603465270718</td><td>List(Sylvester, GA)</td><td>List()</td><td>facebook</td><td>1593603465270718</td><td>UA000000106482722</td></tr><tr><td>Chrome OS</td><td>List(null, null, null)</td><td>pillows</td><td>null</td><td>1593617166243021</td><td>List(Bridgewater Town, MA)</td><td>List()</td><td>google</td><td>1593617166243021</td><td>UA000000106542440</td></tr><tr><td>macOS</td><td>List(null, null, null)</td><td>original</td><td>1593617767125033</td><td>1593619079938606</td><td>List(Los Angeles, CA)</td><td>List()</td><td>google</td><td>1593615315744977</td><td>UA000000106532025</td></tr><tr><td>Windows</td><td>List(null, null, null)</td><td>original</td><td>1593606774016954</td><td>1593607685475848</td><td>List(Seattle, WA)</td><td>List()</td><td>youtube</td><td>1593606774016954</td><td>UA000000106493125</td></tr><tr><td>iOS</td><td>List(null, null, null)</td><td
102216664</td><td>true</td></tr><tr><td>UA000000106497908</td><td>1593818474740259</td><td>true</td></tr><tr><td>UA000000106534103</td><td>1593615679754271</td><td>false</td></tr><tr><td>UA000000106545052</td><td>1593618829356370</td><td>true</td></tr><tr><td>UA000000106524135</td><td>1593613827633094</td><td>false</td></tr><tr><td>UA000000106534680</td><td>1593615792748124</td><td>true</td></tr><tr><td>UA000000106462916</td><td>1593593403534797</td><td>true</td></tr><tr><td>UA000000106506280</td><td>1593610099191094</td><td>false</td></tr><tr><td>UA000000106498888</td><td>1593608333243798</td><td>true</td></tr><tr><td>UA000000106530092</td><td>1593793033157582</td><td>true< ...

# %% [markdown]
# ### Write streaming query results
#
# Take the final streaming DataFrame (our result table) and write it to a file sink in "append" mode.

# %%
checkpointPath = userhome + "/email_traffic/checkpoint"
outputPath = userhome + "/email_traffic/output"

devicesQuery = (emailTrafficDF
                .writeStream
                .outputMode("append")
                .format("parquet")
                .queryName("email_traffic")
                .trigger(processingTime="1 second")
                .option("checkpointLocation", checkpointPath)
                .start(outputPath)
               )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Monitor streaming query
#
# Use the streaming query "handle" to monitor and control it.

# %%
devicesQuery.id
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: &#39;5457259f-b0e0-4f7b-bc4a-e34a2cac69ff&#39;</div>

# %%
devicesQuery.status
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: {&#39;message&#39;: &#39;Getting offsets from FileStreamSource[dbfs:/mnt/training/ecommerce/events/events.parquet]&#39;,
#  &#39;isDataAvailable&#39;: False,
#  &#39;isTriggerActive&#39;: True}</div>

# %%
devicesQuery.lastProgress
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: {&#39;id&#39;: &#39;5457259f-b0e0-4f7b-bc4a-e34a2cac69ff&#39;,
#  &#39;runId&#39;: &#39;2b22f386-f006-4ea9-9ecf-8afab473505e&#39;,
#  &#39;name&#39;: &#39;email_traffic&#39;,
#  &#39;timestamp&#39;: &#39;2022-07-26T07:25:20.000Z&#39;,
#  &#39;batchId&#39;: 4,
#  &#39;numInputRows&#39;: 0,
#  &#39;inputRowsPerSecond&#39;: 0.0,
#  &#39;processedRowsPerSecond&#39;: 0.0,
#  &#39;durationMs&#39;: {&#39;latestOffset&#39;: 73, &#39;triggerExecution&#39;: 73},
#  &#39;stateOperators&#39;: [],
#  &#39;sources&#39;: [{&#39;description&#39;: &#39;FileStreamSource[dbfs:/mnt/training/ecommerce/events/events.parquet]&#39;,
#    &#39;startOffset&#39;: {&#39;logOffset&#39;: 3},
#    &#39;endOffset&#39;: {&#39;logOffset&#39;: 3},
#    &#39;latestOffset&#39;: None,
#    &#39;numInputRows&#39;: 0,
#    &#39;inputRowsPerSecond&#39;: 0.0,
#    &#39;processedRowsPerSecond&#39;: 0.0}],
#  &#39;sink&#39;: {&#39;description&#39;: &#39;FileSink[dbfs:/user/manujkumar.joshi@celebaltech.com/email_traffic/output]&#39;,
#   &#39;numOutputRows&#39;: -1}}</div>

# %%
devicesQuery.awaitTermination(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: False</div>

# %%
devicesQuery.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Coupon Sales Lab
# Process and append streaming data on transactions using coupons.
# 1. Read data stream
# 2. Filter for transactions with coupons codes
# 3. Write streaming query results to Parquet
# 4. Monitor streaming query
# 5. Stop streaming query
#
# ##### Classes
# - <a href="https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.streaming.DataStreamReader.html#pyspark.sql.streaming.DataStreamReader" target="_blank">DataStreamReader</a>
# - <a href="https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.streaming.DataStreamWriter.html#pyspark.sql.streaming.DataStreamWriter" target="_blank">DataStreamWriter</a>
# - <a href="https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.streaming.StreamingQuery.html#pyspark.sql.streaming.StreamingQuery" target="_blank">StreamingQuery</a>

# %% [markdown]
# ### 1. Read data stream
# - Use the schema stored in **`schema`**
# - Set to process 1 file per trigger
# - Read from Parquet files in the source directory specified by **`salesPath`**
#
# Assign the resulting DataFrame to **`df`**.

# %%
schema = "order_id BIGINT, email STRING, transaction_timestamp BIGINT, total_item_quantity BIGINT, purchase_revenue_in_usd DOUBLE, unique_items BIGINT, items ARRAY<STRUCT<coupon: STRING, item_id: STRING, item_name: STRING, item_revenue_in_usd: DOUBLE, price_in_usd: DOUBLE, quantity: BIGINT>>"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TODO
df = (spark
      .readStream
      .schema(schema)
      .option('maxFilesPerTrigger',1)
      .parquet(salesPath)
)
df.isStreaming
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: True</div>

# %% [markdown]
# **CHECK YOUR WORK**

# %%
assert df.isStreaming
assert df.columns == ["order_id", "email", "transaction_timestamp", "total_item_quantity", "purchase_revenue_in_usd", "unique_items", "items"]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### 2. Filter for transactions with coupon codes
# - Explode the **`items`** field in **`df`** with the results replacing the existing **`items`** field
# - Filter for records where **`items.coupon`** is not null
#
# Assign the resulting DataFrame to **`couponSalesDF`**.

# %%
from pyspark.sql.functions import explode
couponSalesDF = (df
                 .withColumn('items',explode(col('items')))
                 .filter(col('items.coupon').isNotNull())
)
display(couponSalesDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>email</th><th>transaction_timestamp</th><th>total_item_quantity</th><th>purchase_revenue_in_usd</th><th>unique_items</th><th>items</th></tr></thead><tbody><tr><td>277029</td><td>ariasamanda12@gmail.com</td><td>1592439049943080</td><td>2</td><td>993.6</td><td>2</td><td>List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1)</td></tr><tr><td>277029</td><td>ariasamanda12@gmail.com</td><td>1592439049943080</td><td>2</td><td>993.6</td><td>2</td><td>List(NEWBED10, P_FOAM_S, Standard Foam Pillow, 53.1, 59.0, 1)</td></tr><tr><td>271875</td><td>jenniferpark@lynn.com</td><td>1592402210938700</td><td>1</td><td>1525.5</td><td>1</td><td>List(NEWBED10, M_PREM_F, Premium Full Mattress, 1525.5, 1695.0, 1)</td></tr><tr><td>287222</td><td>schneidergary@thomas.info</td><td>1592541143972493</td><td>1</td><td>985.5</td><td>1</td><td>List(NEWBED10, M_PREM_T, Premium Twin Mattress, 985.5, 1095.0, 1)</td></tr><tr><td>267814</td><td>teresa43@yahoo.com</td><td>1592334310039252</td><td>2</td><td>1071.0</td><td>1</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 1071.0, 595.0, 2)</td></tr><tr><td>297157</td><td>matthew08@yahoo.com</td><td>1592611197489603</td><td>1</td><td>1525.5</td><td>1</td><td>List(NEWBED10, M_PREM_F, Premium Full Mattress, 1525.5, 1695.0, 1)</td></tr><tr><td>273698</td><td>stephenjohnson@paul.com</td><td>1592415078909439</td><td>1</td><td>940.5</td><td>1</td><td>List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1)</td></tr><tr><td>272527</td><td>zferguson@daniels-taylor.org</td><td>1592407612907648</td><td>1</td><td>535.5</td><td>1</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td></tr><tr><td>273886</td><td>jennifer8546@yahoo.com</td><td>1592416045087762</td><td>1</td><td>940.5</td><td>1</td><td>List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1)</td></tr><tr><td>271162</td><td>jacob21@warren.info</td><td>1592394049326897</td><td>1</td><td>850.5</td><td>1</td><td>List(NEWBED10, M_STAN_F, Standard Full Mattress, 850.5, 945.0, 1)</td></tr><tr><td>284721</td><td>kanecharles@hotmail.com</td><td>1592515134941026</td><td>1</td><td>107.10000000000001</td><td>1</td><td>List(NEWBED10, P_DOWN_S, Standard Down Pillow, 107.10000000000001, 119.0, 1)</td></tr><tr><td>289372</td><td>tina96@hotmail.com</td><td>1592571001307153</td><td>1</td><td>535.5</td><td>1</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td></tr><tr><td>314401</td><td>pbailey@ferrell.com</td><td>1592742260123309</td><td>1</td><td>535.5</td><td>1</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td></tr><tr><td>279274</td><td>lisamiller@gmail.com</td><td>1592483878997436</td><td>1</td><td>535.5</td><td>1</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td></tr><tr><td>287744</td><td>catherinekirk@gmail.com</td><td>1592550931076653</td><td>1</td><td>940.5</td><td>1</td><td>List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1)</td></tr><tr><td>279929</td><td>sydney08@valdez.com</td><td>1592489458161316</td><td>1</td><td>535.5</td><td>1</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td></tr><tr><td>270418</td><td>sandramoore83@yahoo.com</td><td>1592362589480095</td><td>1</td><td>940.5</td><td>1</td><td>List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1)</td></tr><tr><td>292220</td><td>bianca97@blair-mckee.com</td><td>1592586083806119</td><td>1</td><td>850.5</td><td>1</td><td>List(NEWBED10, M_STAN_F, Standard Full Mattress, 850.5, 945.0, 1)</td></tr><tr><td>271040</td><td>jadeblake@hotmail.com</td><td>1592391852058274</td><td>1</td><td>850.5</td><td>1</td><td>List(NEWBED10, M_STAN_F, Standard Full Mattress, 850.5, 945.0, 1)</td></tr><tr><td>286896</td><td>corey96@bell.com</td><td>1592535514869156</td><td>1</td><td>850.5</td><td>1</td><td>L ...

# %% [markdown]
# **CHECK YOUR WORK**

# %%
schemaStr = str(couponSalesDF.schema)
assert "StructField(items,StructType(List(StructField(coupon" in schemaStr, "items column was not exploded"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### 3. Write streaming query results to parquet
# - Configure the streaming query to write Parquet format files in "append" mode
# - Set the query name to "coupon_sales"
# - Set a trigger interval of 1 second
# - Set the checkpoint location to **`couponsCheckpointPath`**
# - Set the output path to **`couponsOutputPath`**
#
# Start the streaming query and assign the resulting handle to **`couponSalesQuery`**.

# %%
# TODO
couponsCheckpointPath = workingDir + "/coupon-sales/checkpoint"
couponsOutputPath = workingDir + "/coupon-sales/output"

couponSalesQuery = (couponSalesDF
                    .writeStream
                    .outputMode('append')
                    .format('parquet')
                    .queryName('coupon_sales')
                    .trigger(processingTime='1 second')
                    .option("checkpointLocation", couponsCheckpointPath)
                    .start(couponsOutputPath)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **CHECK YOUR WORK**

# %%
untilStreamIsReady("coupon_sales")
assert couponSalesQuery.isActive
assert len(dbutils.fs.ls(couponsOutputPath)) > 0
assert len(dbutils.fs.ls(couponsCheckpointPath)) > 0
assert "coupon_sales" in couponSalesQuery.lastProgress["name"]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The stream coupon_sales is active and ready.
# </div>

# %% [markdown]
# ### 4. Monitor streaming query
# - Get the ID of streaming query and store it in **`queryID`**
# - Get the status of streaming query and store it in **`queryStatus`**

# %%
# TODO
queryID = couponSalesQuery.id
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TODO
queryStatus = couponSalesQuery.status
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **CHECK YOUR WORK**

# %%
assert type(queryID) == str
assert list(queryStatus.keys()) == ["message", "isDataAvailable", "isTriggerActive"]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### 5. Stop streaming query
# - Stop the streaming query

# %%
# TODO
couponSalesQuery.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **CHECK YOUR WORK**

# %%
assert not couponSalesQuery.isActive
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### 6. Verify the records were written in Parquet format

# %%
# ANSWER
display(spark.read.parquet(couponsOutputPath))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>email</th><th>transaction_timestamp</th><th>total_item_quantity</th><th>purchase_revenue_in_usd</th><th>unique_items</th><th>items</th></tr></thead><tbody><tr><td>282611</td><td>bmurillo@hotmail.com</td><td>1592504237604072</td><td>1</td><td>940.5</td><td>1</td><td>List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1)</td></tr><tr><td>283949</td><td>whardin@hotmail.com</td><td>1592510720760323</td><td>1</td><td>535.5</td><td>1</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td></tr><tr><td>264191</td><td>maxwelltara@edwards.com</td><td>1592306255847870</td><td>2</td><td>993.6</td><td>2</td><td>List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1)</td></tr><tr><td>264191</td><td>maxwelltara@edwards.com</td><td>1592306255847870</td><td>2</td><td>993.6</td><td>2</td><td>List(NEWBED10, P_FOAM_S, Standard Foam Pillow, 53.1, 59.0, 1)</td></tr><tr><td>286727</td><td>rojasjorge@yahoo.com</td><td>1592533048926949</td><td>1</td><td>535.5</td><td>1</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td></tr><tr><td>287573</td><td>marmstrong46@hotmail.com</td><td>1592547727220317</td><td>1</td><td>53.1</td><td>1</td><td>List(NEWBED10, P_FOAM_S, Standard Foam Pillow, 53.1, 59.0, 1)</td></tr><tr><td>271597</td><td>johnsonderrick@yahoo.com</td><td>1592399808941985</td><td>5</td><td>2846.7</td><td>5</td><td>List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1)</td></tr><tr><td>271597</td><td>johnsonderrick@yahoo.com</td><td>1592399808941985</td><td>5</td><td>2846.7</td><td>5</td><td>List(NEWBED10, P_DOWN_K, King Down Pillow, 143.1, 159.0, 1)</td></tr><tr><td>271597</td><td>johnsonderrick@yahoo.com</td><td>1592399808941985</td><td>5</td><td>2846.7</td><td>5</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td></tr><tr><td>271597</td><td>johnsonderrick@yahoo.com</td><td>1592399808941985</td><td>5</td><td>2846.7</td><td>5</td><td>List(NEWBED10, M_PREM_T, Premium Twin Mattress, 985.5, 1095.0, 1)</td></tr><tr><td>271597</td><td>johnsonderrick@yahoo.com</td><td>1592399808941985</td><td>5</td><td>2846.7</td><td>5</td><td>List(NEWBED10, P_DOWN_S, Standard Down Pillow, 107.10000000000001, 119.0, 1)</td></tr><tr><td>278696</td><td>ericzimmerman@valentine.com</td><td>1592477039776439</td><td>1</td><td>850.5</td><td>1</td><td>List(NEWBED10, M_STAN_F, Standard Full Mattress, 850.5, 945.0, 1)</td></tr><tr><td>284289</td><td>gtravis@sosa.com</td><td>1592512529113827</td><td>1</td><td>1075.5</td><td>1</td><td>List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1)</td></tr><tr><td>291595</td><td>wilsonteresa@walsh.net</td><td>1592583392587031</td><td>1</td><td>940.5</td><td>1</td><td>List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1)</td></tr><tr><td>270485</td><td>ashleylevy@gonzalez.com</td><td>1592365363632845</td><td>1</td><td>535.5</td><td>1</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td></tr><tr><td>266071</td><td>kbennett@gmail.com</td><td>1592324218038408</td><td>1</td><td>985.5</td><td>1</td><td>List(NEWBED10, M_PREM_T, Premium Twin Mattress, 985.5, 1095.0, 1)</td></tr><tr><td>286352</td><td>bennettzachary88@gmail.com</td><td>1592528275242825</td><td>1</td><td>940.5</td><td>1</td><td>List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1)</td></tr><tr><td>270184</td><td>barryandrew@roy-gonzalez.com</td><td>1592356069801191</td><td>1</td><td>1795.5</td><td>1</td><td>List(NEWBED10, M_PREM_K, Premium King Mattress, 1795.5, 1995.0, 1)</td></tr><tr><td>277674</td><td>brittany447@yahoo.com</td><td>1592450937710949</td><td>1</td><td>535.5</td><td>1</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td></tr><tr><td>287487</td><td>awilson@gmail.com</td><td>1592545888248430</td><td>1</td><td>535.5</td><td>1</td><td>L ...

# %% [markdown]
# ### Classroom Cleanup
# Run the cell below to clean up resources.

# %%
# %run ./Includes/Classroom-Cleanup
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Stopping 3 streams
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# -sandbox
# &copy; 2022 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="https://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="https://help.databricks.com/">Support</a>
